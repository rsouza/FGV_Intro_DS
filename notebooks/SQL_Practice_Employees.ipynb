# %% [markdown]
# # SQL Practice on Employees Database

# %% [markdown]
# This notebook contains practice questions and exercises using a sample employees database. You can find some good questions to practice with at [w3resource](https://www.w3resource.com/sql-exercises/employee-database-exercise/sql-employee-database-exercise-1.php).

# %% [markdown]
# If you're interested in following along in your own Jupyter notebook (or making a copy of this one), you can read my guide on Medium – [How to run and analyse SQL queries in Pandas in Jupyter](https://medium.com/@corraljrmiguel/how-to-run-and-analyze-sql-queries-with-pandas-in-jupyter-7f02503cf46).

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Employees-Database-Schema" data-toc-modified-id="Employees-Database-Schema-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Employees Database Schema</a></span></li><li><span><a href="#Basics" data-toc-modified-id="Basics-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Basics</a></span><ul class="toc-item"><li><span><a href="#Select-all-the-rows-in-the-employees-table" data-toc-modified-id="Select-all-the-rows-in-the-employees-table-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Select all the rows in the employees table</a></span></li><li><span><a href="#Write-a-query-to-show-the-full-names-of-employees" data-toc-modified-id="Write-a-query-to-show-the-full-names-of-employees-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Write a query to show the full names of employees</a></span></li><li><span><a href="#Find-all-employees-who-are-also-managers" data-toc-modified-id="Find-all-employees-who-are-also-managers-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Find all employees who are also managers</a></span></li><li><span><a href="#Find-the-5th-highest-salary" data-toc-modified-id="Find-the-5th-highest-salary-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Find the 5th highest salary</a></span></li><li><span><a href="#Find-duplicate-rows-in-the-employees-table" data-toc-modified-id="Find-duplicate-rows-in-the-employees-table-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Find duplicate rows in the employees table</a></span></li><li><span><a href="#Show-unique-job-titles-per-department" data-toc-modified-id="Show-unique-job-titles-per-department-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Show unique job titles per department</a></span></li></ul></li><li><span><a href="#Aggregating" data-toc-modified-id="Aggregating-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Aggregating</a></span><ul class="toc-item"><li><span><a href="#Show-the-average-salaries-per-job-title" data-toc-modified-id="Show-the-average-salaries-per-job-title-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Show the average salaries per job title</a></span></li><li><span><a href="#Show-the-total-number-of-employees-per-job-title-and-the-percentage-of-the-total-per-title" data-toc-modified-id="Show-the-total-number-of-employees-per-job-title-and-the-percentage-of-the-total-per-title-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Show the total number of employees per job title and the percentage of the total per title</a></span></li><li><span><a href="#Group-employees-into-3-salary-groups" data-toc-modified-id="Group-employees-into-3-salary-groups-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Group employees into 3 salary groups</a></span></li></ul></li><li><span><a href="#Joining" data-toc-modified-id="Joining-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Joining</a></span><ul class="toc-item"><li><span><a href="#Show-all-employees-and-include-their-employee-id,-full-names,-job-titles,-and-the-department-name" data-toc-modified-id="Show-all-employees-and-include-their-employee-id,-full-names,-job-titles,-and-the-department-name-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Show all employees and include their employee id, full names, job titles, and the department name</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Setup

# %% [markdown]
# In order to run SQL queries in a Jupyter notebook, you'll need to run the two cells below.

# %%
# load the ipython-sql extension
# %load_ext sql

# %% [markdown]
# If you're using your own Jupyter notebook, you'll need to enter your own credentials.

# %%
import getpass
# define user & password
user = 'miguel'
password = getpass.getpass()
connection_string = f'mysql+pymysql://{user}:{password}@localhost:3306/employees'
# %sql $connection_string
# Out:
#  ··················
# 'Connected: miguel@employees'

# %% [markdown]
# The configuration cell below is to simply limit the output to 10 rows.

# %%
# %config SqlMagic.displaylimit=10

# %% [markdown]
# ## Employees Database Schema

# %% [markdown]
# ![schema](./img/employees-schema.png)

# %% [markdown]
# ## Basics

# %% [markdown]
# ### Select all the rows in the employees table

# %%
# %%sql
# SELECT * FROM employees;
# Out:
#  * mysql+pymysql://miguel:***@localhost:3306/employees
# 300024 rows affected.
# [(10001, datetime.date(1953, 9, 2), 'Georgi', 'Facello', 'M', datetime.date(1986, 6, 26)),
#  (10002, datetime.date(1964, 6, 2), 'Bezalel', 'Simmel', 'F', datetime.date(1985, 11, 21)),
#  (10003, datetime.date(1959, 12, 3), 'Parto', 'Bamford', 'M', datetime.date(1986, 8, 28)),
#  (10004, datetime.date(1954, 5, 1), 'Chirstian', 'Koblick', 'M', datetime.date(1986, 12, 1)),
#  (10005, datetime.date(1955, 1, 21), 'Kyoichi', 'Maliniak', 'M', datetime.date(1989, 9, 12)),
#  (10006, datetime.date(1953, 4, 20), 'Anneke', 'Preusig', 'F', datetime.date(1989, 6, 2)),
#  (10007, datetime.date(1957, 5, 23), 'Tzvetan', 'Zielinski', 'F', datetime.date(1989, 2, 10)),
#  (10008, datetime.date(1958, 2, 19), 'Saniya', 'Kalloufi', 'M', datetime.date(1994, 9, 15)),
#  (10009, datetime.date(1952, 4, 19), 'Sumant', 'Peac', 'F', datetime.date(1985, 2, 18)),
#  (10010, datetime.date(1963, 6, 1), 'Duangkaew', 'Piveteau', 'F', datetime.date(1989, 8, 24)),
#  (10011, datetime.date(1953, 11, 7), 'Mary', 'Sluis', 'F', datetime.date(1990, 1, 22)),
#  (10012, datetime.date(1960, 10, 4), 'Patricio', 'Bridgland', 'M', datetime.date(1992, 12, 18)),
#  (10013, datetime.date(1963, 6, 7), 'Eberhardt', 'Terkki', 'M', datetime.date(1985, 10, 20)),
#  (10014, datetime.date(1956, 2, 12), 'Berni', 'Genin', 'M', datetime.date(1987, 3, 11)),
#  (10015, datetime.date(1959, 8, 19), 'Guoxiang', 'Nooteboom', 'M', datetime.date(1987, 7, 2)),
#  (10016, datetime.date(1961, 5, 2), 'Kazuhito', 'Cappelletti', 'M', datetime.date(1995, 1, 27)),
#  (10017, datetime.date(1958, 7, 6), 'Cristinel', 'Bouloucos', 'F', datetime.date(1993, 8, 3)),
#  (10018, datetime.date(1954, 6, 19), 'Kazuhide', 'Peha', 'F', datetime.date(1987, 4, 3)),
#  (10019, datetime.date(1953, 1, 23), 'Lillian', 'Haddadi', 'M', datetime.date(1999, 4, 30)),
#  (10020, datetime.date(1952, 12, 24), 'Mayuko', 'Warwick', 'M', datetime.date(1991, 1, 26)),
#  (10021, datetime.date(1960, 2, 20), 'Ramzi', 'Erde', 'M', datetime.date(1988, 2, 10)),
#  (10022, datetime.date(1952, 7, 8), 'Shahaf', 'Famili', 'M', datetime.date(1995, 8, 22)),
#  (10023, datetime.date(1953, 9, 29), 'Bojan', 'Montemayor', 'F', datetime.date(1989, 12, 17)),
#  (10024, datetime.date(1958, 9, 5), 'Suzette', 'Pettey', 'F', datetime.date(1997, 5, 19)),
#  (10025, datetime.date(1958, 10, 31), 'Prasadram', 'Heyers', 'M', datetime.date(1987, 8, 17)),
#  (10026, datetime.date(1953, 4, 3), 'Yongqiao', 'Berztiss', 'M', datetime.date(1995, 3, 20)),
#  (10027, datetime.date(1962, 7, 10), 'Divier', 'Reistad', 'F', datetime.date(1989, 7, 7)),
#  (10028, datetime.date(1963, 11, 26), 'Domenick', 'Tempesti', 'M', datetime.date(1991, 10, 22)),
#  (10029, datetime.date(1956, 12, 13), 'Otmar', 'Herbst', 'M', datetime.date(1985, 11, 20)),
#  (10030, datetime.date(1958, 7, 14), 'Elvis', 'Demeyer', 'M', datetime.date(1994, 2, 17)),
#  (10031, datetime.date(1959, 1, 27), 'Karsten', 'Joslin', 'M', datetime.date(1991, 9, 1)),
#  (10032, datetime.date(1960, 8, 9), 'Jeong', 'Reistad', 'F', datetime.date(1990, 6, 20)),
#  (10033, datetime.date(1956, 11, 14), 'Arif', 'Merlo', 'M', datetime.date(1987, 3, 18)),
#  (10034, datetime.date(1962, 12, 29), 'Bader', 'Swan', 'M', datetime.date(1988, 9, 21)),
#  (10035, datetime.date(1953, 2, 8), 'Alain', 'Chappelet', 'M', datetime.date(1988, 9, 5)),
#  (10036, datetime.date(1959, 8, 10), 'Adamantios', 'Portugali', 'M', datetime.date(1992, 1, 3)),
#  (10037, datetime.date(1963, 7, 22), 'Pradeep', 'Makrucki', 'M', datetime.date(1990, 12, 5)),
#  (10038, datetime.date(1960, 7, 20), 'Huan', 'Lortz', 'M', datetime.date(1989, 9, 20)),
#  (10039, datetime.date(1959, 10, 1), 'Alejandro', 'Brender', 'M', datetime.date(1988, 1, 19)),
#  (10040, datetime.date(1959, 9, 13), 'Weiyi', 'Meriste', 'F', datetime.date(1993, 2, 14)),
#  (10041, datetime.date(1959, 8, 27), 'Uri', 'Lenart', 'F', datetime.date(1989, 11, 12)),
#  (10042, datetime.date(1956, 2, 26), 'Magy', 'Stamatiou', 'F', datetime.date(1993, 3, 21)),
#  (10043, datetime.date(1960, 9, 19), 'Yishay', 'Tzvieli', 'M', datetime.date(1990, 10, 20)),
#  (10044, datetime.date(1961, 9, 21), 'Mingsen', 'Casley', 'F', datetime.date(1994, 5, 21)),
#  (10045, datetime.date(1957, 8, 14), 'Moss', 'Shanbhogue', 'M', datetime.date(1989, 9, 2)),
#  (10046, datetime.date(1960, 7, 23), 'Lucien', 'Rosenbaum', 'M', datetime.date(1992, 6, 20)),
#  (10047, datetime.date(1952, 6, 29), 'Zvonko', 'Nyanchama', 'M', datetime.date(1989, 3, 31)),
#  (10048, datetime.date(1963, 7, 11), 'Florian', 'Syrotiuk', 'M', datetime.date(1985, 2, 24)),
#  (10049, datetime.date(1961, 4, 24), 'Basil', 'Tramer', 'F', datetime.date(1992, 5, 4)),
#  (10050, datetime.date(1958, 5, 21), 'Yinghua', 'Dredge', 'M', datetime.date(1990, 12, 25)),
#  (10051, datetime.date(1953, 7, 28), 'Hidefumi', 'Caine', 'M', datetime.date(1992, 10, 15)),
#  (10052, datetime.date(1961, 2, 26), 'Heping', 'Nitsch', 'M', datetime.date(1988, 5, 21)),
#  (10053, datetime.date(1954, 9, 13), 'Sanjiv', 'Zschoche', 'F', datetime.date(1986, 2, 4)),
#  (10054, datetime.date(1957, 4, 4), 'Mayumi', 'Schueller', 'M', datetime.date(1995, 3, 13)),
#  (10055, datetime.date(1956, 6, 6), 'Georgy', 'Dredge', 'M', datetime.date(1992, 4, 27)),
#  (10056, datetime.date(1961, 9, 1), 'Brendon', 'Bernini', 'F', datetime.date(1990, 2, 1)),
#  (10057, datetime.date(1954, 5, 30), 'Ebbe', 'Callaway', 'F', datetime.date(1992, 1, 15)),
#  (10058, datetime.date(1954, 10, 1), 'Berhard', 'McFarlin', 'M', datetime.date(1987, 4, 13)),
#  (10059, datetime.date(1953, 9, 19), 'Alejandro', 'McAlpine', 'F', datetime.date(1991, 6, 26)),
#  (10060, datetime.date(1961, 10, 15), 'Breannda', 'Billingsley', 'M', datetime.date(1987, 11, 2)),
#  (10061, datetime.date(1962, 10, 19), 'Tse', 'Herber', 'M', datetime.date(1985, 9, 17)),
#  (10062, datetime.date(1961, 11, 2), 'Anoosh', 'Peyn', 'M', datetime.date(1991, 8, 30)),
#  (10063, datetime.date(1952, 8, 6), 'Gino', 'Leonhardt', 'F', datetime.date(1989, 4, 8)),
#  (10064, datetime.date(1959, 4, 7), 'Udi', 'Jansch', 'M', datetime.date(1985, 11, 20)),
#  (10065, datetime.date(1963, 4, 14), 'Satosi', 'Awdeh', 'M', datetime.date(1988, 5, 18)),
#  (10066, datetime.date(1952, 11, 13), 'Kwee', 'Schusler', 'M', datetime.date(1986, 2, 26)),
#  (10067, datetime.date(1953, 1, 7), 'Claudi', 'Stavenow', 'M', datetime.date(1987, 3, 4)),
#  (10068, datetime.date(1962, 11, 26), 'Charlene', 'Brattka', 'M', datetime.date(1987, 8, 7)),
#  (10069, datetime.date(1960, 9, 6), 'Margareta', 'Bierman', 'F', datetime.date(1989, 11, 5)),
#  (10070, datetime.date(1955, 8, 20), 'Reuven', 'Garigliano', 'M', datetime.date(1985, 10, 14)),
#  (10071, datetime.date(1958, 1, 21), 'Hisao', 'Lipner', 'M', datetime.date(1987, 10, 1)),
#  (10072, datetime.date(1952, 5, 15), 'Hironoby', 'Sidou', 'F', datetime.date(1988, 7, 21)),
#  (10073, datetime.date(1954, 2, 23), 'Shir', 'McClurg', 'M', datetime.date(1991, 12, 1)),
#  (10074, datetime.date(1955, 8, 28), 'Mokhtar', 'Bernatsky', 'F', datetime.date(1990, 8, 13)),
#  (10075, datetime.date(1960, 3, 9), 'Gao', 'Dolinsky', 'F', datetime.date(1987, 3, 19)),
#  (10076, datetime.date(1952, 6, 13), 'Erez', 'Ritzmann', 'F', datetime.date(1985, 7, 9)),
#  (10077, datetime.date(1964, 4, 18), 'Mona', 'Azuma', 'M', datetime.date(1990, 3, 2)),
#  (10078, datetime.date(1959, 12, 25), 'Danel', 'Mondadori', 'F', datetime.date(1987, 5, 26)),
#  (10079, datetime.date(1961, 10, 5), 'Kshitij', 'Gils', 'F', datetime.date(1986, 3, 27)),
#  (10080, datetime.date(1957, 12, 3), 'Premal', 'Baek', 'M', datetime.date(1985, 11, 19)),
#  (10081, datetime.date(1960, 12, 17), 'Zhongwei', 'Rosen', 'M', datetime.date(1986, 10, 30)),
#  (10082, datetime.date(1963, 9, 9), 'Parviz', 'Lortz', 'M', datetime.date(1990, 1, 3)),
#  (10083, datetime.date(1959, 7, 23), 'Vishv', 'Zockler', 'M', datetime.date(1987, 3, 31)),
#  (10084, datetime.date(1960, 5, 25), 'Tuval', 'Kalloufi', 'M', datetime.date(1995, 12, 15)),
#  (10085, datetime.date(1962, 11, 7), 'Kenroku', 'Malabarba', 'M', datetime.date(1994, 4, 9)),
#  (10086, datetime.date(1962, 11, 19), 'Somnath', 'Foote', 'M', datetime.date(1990, 2, 16)),
#  (10087, datetime.date(1959, 7, 23), 'Xinglin', 'Eugenio', 'F', datetime.date(1986, 9, 8)),
#  (10088, datetime.date(1954, 2, 25), 'Jungsoon', 'Syrzycki', 'F', datetime.date(1988, 9, 2)),
#  (10089, datetime.date(1963, 3, 21), 'Sudharsan', 'Flasterstein', 'F', datetime.date(1986, 8, 12)),
#  (10090, datetime.date(1961, 5, 30), 'Kendra', 'Hofting', 'M', datetime.date(1986, 3, 14)),
#  (10091, datetime.date(1955, 10, 4), 'Amabile', 'Gomatam', 'M', datetime.date(1992, 11, 18)),
#  (10092, datetime.date(1964, 10, 18), 'Valdiodio', 'Niizuma', 'F', datetime.date(1989, 9, 22)),
#  (10093, datetime.date(1964, 6, 11), 'Sailaja', 'Desikan', 'M', datetime.date(1996, 11, 5)),
#  (10094, datetime.date(1957, 5, 25), 'Arumugam', 'Ossenbruggen', 'F', datetime.date(1987, 4, 18)),
#  (10095, datetime.date(1965, 1, 3), 'Hilari', 'Morton', 'M', datetime.date(1986, 7, 15)),
#  (10096, datetime.date(1954, 9, 16), 'Jayson', 'Mandell', 'M', datetime.date(1990, 1, 14)),
#  (10097, datetime.date(1952, 2, 27), 'Remzi', 'Waschkowski', 'M', datetime.date(1990, 9, 15)),
#  (10098, datetime.date(1961, 9, 23), 'Sreekrishna', 'Servieres', 'F', datetime.date(1985, 5, 13)),
#  (10099, datetime.date(1956, 5, 25), 'Valter', 'Sullins', 'F', datetime.date(1988, 10, 18)),
#  (10100, datetime.date(1953, 4, 21), 'Hironobu', 'Haraldson', 'F', datetime.date(1987, 9, 21)),
#  (10101, datetime.date(1952, 4, 15), 'Perla', 'Heyers', 'F', datetime.date(1992, 12, 28)),
#  (10102, datetime.date(1959, 11, 4), 'Paraskevi', 'Luby', 'F', datetime.date(1994, 1, 26)),
#  (10103, datetime.date(1953, 11, 26), 'Akemi', 'Birch', 'M', datetime.date(1986, 12, 2)),
#  (10104, datetime.date(1961, 11, 19), 'Xinyu', 'Warwick', 'M', datetime.date(1987, 4, 16)),
#  (10105, datetime.date(1962, 2, 5), 'Hironoby', 'Piveteau', 'M', datetime.date(1999, 3, 23)),
#  (10106, datetime.date(1952, 8, 29), 'Eben', 'Aingworth', 'M', datetime.date(1990, 12, 19)),
#  (10107, datetime.date(1956, 6, 13), 'Dung', 'Baca', 'F', datetime.date(1994, 3, 22)),
#  (10108, datetime.date(1952, 4, 7), 'Lunjin', 'Giveon', 'M', datetime.date(1986, 10, 2)),
#  (10109, datetime.date(1958, 11, 25), 'Mariusz', 'Prampolini', 'F', datetime.date(1993, 6, 16)),
#  (10110, datetime.date(1957, 3, 7), 'Xuejia', 'Ullian', 'F', datetime.date(1986, 8, 22)),
#  (10111, datetime.date(1963, 8, 29), 'Hugo', 'Rosis', 'F', datetime.date(1988, 6, 19)),
#  (10112, datetime.date(1963, 8, 13), 'Yuichiro', 'Swick', 'F', datetime.date(1985, 10, 8)),
#  (10113, datetime.date(1963, 11, 13), 'Jaewon', 'Syrzycki', 'M', datetime.date(1989, 12, 24)),
#  (10114, datetime.date(1957, 2, 16), 'Munir', 'Demeyer', 'F', datetime.date(1992, 7, 17)),
#  (10115, datetime.date(1964, 12, 25), 'Chikara', 'Rissland', 'M', datetime.date(1986, 1, 23)),
#  (10116, datetime.date(1955, 8, 26), 'Dayanand', 'Czap', 'F', datetime.date(1985, 5, 28)),
#  (10117, datetime.date(1961, 10, 24), 'Kiyotoshi', 'Blokdijk', 'F', datetime.date(1990, 5, 28)),
#  (10118, datetime.date(1957, 3, 29), 'Zhonghui', 'Zyda', 'F', datetime.date(1990, 9, 13)),
#  (10119, datetime.date(1960, 12, 1), 'Domenick', 'Peltason', 'M', datetime.date(1986, 3, 14)),
#  (10120, datetime.date(1960, 3, 26), 'Armond', 'Fairtlough', 'F', datetime.date(1996, 7, 6)),
#  (10121, datetime.date(1962, 7, 14), 'Guoxiang', 'Ramsay', 'M', datetime.date(1989, 5, 3)),
#  (10122, datetime.date(1965, 1, 19), 'Ohad', 'Esposito', 'M', datetime.date(1992, 12, 23)),
#  (10123, datetime.date(1962, 5, 12), 'Hinrich', 'Randi', 'M', datetime.date(1993, 1, 15)),
#  (10124, datetime.date(1962, 5, 23), 'Geraldo', 'Marwedel', 'M', datetime.date(1991, 9, 5)),
#  (10125, datetime.date(1957, 9, 13), 'Syozo', 'Hiltgen', 'F', datetime.date(1990, 10, 26)),
#  (10126, datetime.date(1954, 8, 7), 'Kayoko', 'Valtorta', 'M', datetime.date(1985, 9, 8)),
#  (10127, datetime.date(1952, 2, 24), 'Subir', 'Baja', 'F', datetime.date(1989, 1, 14)),
#  (10128, datetime.date(1958, 2, 15), 'Babette', 'Lamba', 'F', datetime.date(1988, 6, 6)),
#  (10129, datetime.date(1955, 12, 2), 'Armond', 'Peir', 'M', datetime.date(1985, 12, 10)),
#  (10130, datetime.date(1955, 4, 27), 'Nishit', 'Casperson', 'M', datetime.date(1988, 6, 21)),
#  (10131, datetime.date(1952, 2, 19), 'Magdalena', 'Eldridge', 'M', datetime.date(1994, 11, 17)),
#  (10132, datetime.date(1956, 12, 15), 'Ayakannu', 'Skrikant', 'M', datetime.date(1994, 10, 30)),
#  (10133, datetime.date(1963, 12, 12), 'Giri', 'Isaak', 'M', datetime.date(1985, 12, 15)),
#  (10134, datetime.date(1953, 4, 15), 'Diederik', 'Siprelle', 'M', datetime.date(1987, 12, 12)),
#  (10135, datetime.date(1956, 12, 23), 'Nathan', 'Monkewich', 'M', datetime.date(1988, 2, 19)),
#  (10136, datetime.date(1961, 9, 14), 'Zissis', 'Pintelas', 'M', datetime.date(1986, 2, 11)),
#  (10137, datetime.date(1959, 7, 30), 'Maren', 'Hutton', 'M', datetime.date(1985, 2, 18)),
#  (10138, datetime.date(1955, 4, 24), 'Perry', 'Shimshoni', 'M', datetime.date(1986, 9, 18)),
#  (10139, datetime.date(1963, 3, 3), 'Ewing', 'Foong', 'F', datetime.date(1998, 3, 15)),
#  (10140, datetime.date(1957, 3, 11), 'Yucel', 'Auria', 'F', datetime.date(1991, 3, 14)),
#  (10141, datetime.date(1960, 1, 17), 'Shahaf', 'Ishibashi', 'F', datetime.date(1993, 5, 6)),
#  (10142, datetime.date(1956, 8, 29), 'Tzvetan', 'Hettesheimer', 'M', datetime.date(1993, 10, 28)),
#  (10143, datetime.date(1961, 7, 16), 'Sakthirel', 'Bakhtari', 'M', datetime.date(1988, 9, 30)),
#  (10144, datetime.date(1959, 6, 17), 'Marla', 'Brendel', 'M', datetime.date(1985, 10, 14)),
#  (10145, datetime.date(1956, 3, 30), 'Akemi', 'Esposito', 'F', datetime.date(1987, 8, 1)),
#  (10146, datetime.date(1959, 1, 12), 'Chenyi', 'Syang', 'M', datetime.date(1988, 6, 28)),
#  (10147, datetime.date(1964, 10, 13), 'Kazuhito', 'Encarnacion', 'M', datetime.date(1986, 8, 21)),
#  (10148, datetime.date(1957, 10, 4), 'Douadi', 'Azumi', 'M', datetime.date(1995, 10, 10)),
#  (10149, datetime.date(1953, 5, 20), 'Xiadong', 'Perry', 'F', datetime.date(1986, 11, 5)),
#  (10150, datetime.date(1955, 1, 29), 'Zhenbing', 'Perng', 'F', datetime.date(1986, 11, 16)),
#  (10151, datetime.date(1959, 3, 6), 'Itzchak', 'Lichtner', 'M', datetime.date(1990, 4, 10)),
#  (10152, datetime.date(1954, 12, 1), 'Jaques', 'Munro', 'F', datetime.date(1986, 1, 27)),
#  (10153, datetime.date(1955, 12, 15), 'Heekeun', 'Majewski', 'M', datetime.date(1987, 4, 8)),
#  (10154, datetime.date(1957, 1, 17), 'Abdulah', 'Thibadeau', 'F', datetime.date(1990, 12, 12)),
#  (10155, datetime.date(1959, 12, 7), 'Adas', 'Nastansky', 'M', datetime.date(1990, 1, 5)),
#  (10156, datetime.date(1964, 9, 19), 'Sumali', 'Fargier', 'M', datetime.date(1985, 3, 10)),
#  (10157, datetime.date(1954, 4, 23), 'Nigel', 'Aloisi', 'M', datetime.date(1985, 11, 2)),
#  (10158, datetime.date(1958, 4, 1), 'Khedija', 'Mitsuhashi', 'M', datetime.date(1986, 1, 29)),
#  (10159, datetime.date(1955, 3, 3), 'Serif', 'Buescher', 'M', datetime.date(1991, 5, 29)),
#  (10160, datetime.date(1953, 10, 18), 'Debatosh', 'Khasidashvili', 'M', datetime.date(1989, 1, 30)),
#  (10161, datetime.date(1953, 4, 6), 'Hairong', 'Mellouli', 'F', datetime.date(1988, 4, 3)),
#  (10162, datetime.date(1957, 10, 5), 'Florina', 'Eugenio', 'M', datetime.date(1991, 5, 1)),
#  (10163, datetime.date(1952, 9, 17), 'Karsten', 'Szmurlo', 'M', datetime.date(1989, 7, 19)),
#  (10164, datetime.date(1956, 1, 19), 'Jagoda', 'Braunmuhl', 'M', datetime.date(1985, 11, 12)),
#  (10165, datetime.date(1960, 6, 16), 'Miyeon', 'Macedo', 'M', datetime.date(1988, 5, 17)),
#  (10166, datetime.date(1953, 5, 10), 'Samphel', 'Siegrist', 'F', datetime.date(1993, 1, 1)),
#  (10167, datetime.date(1958, 5, 23), 'Duangkaew', 'Rassart', 'M', datetime.date(1992, 4, 4)),
#  (10168, datetime.date(1964, 9, 11), 'Dharmaraja', 'Stassinopoulos', 'M', datetime.date(1986, 12, 6)),
#  (10169, datetime.date(1961, 5, 3), 'Sampalli', 'Snedden', 'F', datetime.date(1992, 7, 24)),
#  (10170, datetime.date(1960, 10, 3), 'Kasturi', 'Jenevein', 'F', datetime.date(1986, 1, 2)),
#  (10171, datetime.date(1957, 9, 11), 'Herbert', 'Trachtenberg', 'M', datetime.date(1989, 7, 22)),
#  (10172, datetime.date(1957, 3, 25), 'Shigeu', 'Matzen', 'F', datetime.date(1995, 10, 13)),
#  (10173, datetime.date(1962, 10, 28), 'Shrikanth', 'Mahmud', 'M', datetime.date(1992, 3, 21)),
#  (10174, datetime.date(1959, 5, 15), 'Badri', 'Furudate', 'M', datetime.date(1987, 6, 1)),
#  (10175, datetime.date(1960, 1, 11), 'Aleksandar', 'Ananiadou', 'F', datetime.date(1988, 1, 11)),
#  (10176, datetime.date(1957, 1, 24), 'Brendon', 'Lenart', 'F', datetime.date(1994, 12, 22)),
#  (10177, datetime.date(1954, 11, 8), 'Pragnesh', 'Iisaka', 'M', datetime.date(1993, 2, 6)),
#  (10178, datetime.date(1963, 3, 13), 'Valery', 'Litvinov', 'M', datetime.date(1986, 10, 7)),
#  (10179, datetime.date(1961, 11, 25), 'Deniz', 'Duclos', 'F', datetime.date(1990, 10, 4)),
#  (10180, datetime.date(1956, 1, 29), 'Shaw', 'Wendorf', 'M', datetime.date(1986, 2, 25)),
#  (10181, datetime.date(1963, 1, 22), 'Sibyl', 'Nooteboom', 'M', datetime.date(1988, 6, 22)),
#  (10182, datetime.date(1961, 2, 4), 'Moriyoshi', 'Merey', 'F', datetime.date(1990, 9, 2)),
#  (10183, datetime.date(1954, 10, 17), 'Mechthild', 'Bonifati', 'M', datetime.date(1996, 8, 11)),
#  (10184, datetime.date(1957, 5, 22), 'Mihalis', 'Lowrie', 'M', datetime.date(1987, 10, 29)),
#  (10185, datetime.date(1959, 12, 5), 'Duro', 'Sidhu', 'F', datetime.date(1986, 3, 1)),
#  (10186, datetime.date(1953, 7, 16), 'Shigehito', 'Kropatsch', 'M', datetime.date(1986, 3, 28)),
#  (10187, datetime.date(1961, 5, 26), 'Tommaso', 'Narwekar', 'F', datetime.date(1991, 6, 1)),
#  (10188, datetime.date(1956, 7, 13), 'Christ', 'Muchinsky', 'F', datetime.date(1987, 8, 27)),
#  (10189, datetime.date(1955, 11, 12), 'Khalid', 'Erva', 'M', datetime.date(1989, 10, 5)),
#  (10190, datetime.date(1964, 12, 11), 'Arve', 'Fairtlough', 'F', datetime.date(1986, 6, 23)),
#  (10191, datetime.date(1959, 4, 8), 'Zdislav', 'Nastansky', 'M', datetime.date(1986, 4, 10)),
#  (10192, datetime.date(1960, 9, 16), 'Mohua', 'Falck', 'M', datetime.date(1988, 6, 13)),
#  (10193, datetime.date(1960, 6, 29), 'Masaru', 'Cheshire', 'M', datetime.date(1991, 7, 28)),
#  (10194, datetime.date(1954, 1, 29), 'Josyula', 'Hofmeyr', 'F', datetime.date(1989, 5, 15)),
#  (10195, datetime.date(1963, 11, 13), 'Annemarie', 'Redmiles', 'M', datetime.date(1985, 2, 15)),
#  (10196, datetime.date(1954, 1, 27), 'Marc', 'Hellwagner', 'M', datetime.date(1994, 11, 16)),
#  (10197, datetime.date(1963, 8, 6), 'Kasidit', 'Krzyzanowski', 'F', datetime.date(1993, 11, 22)),
#  (10198, datetime.date(1953, 5, 28), 'Pranav', 'Furedi', 'M', datetime.date(1985, 8, 31)),
#  (10199, datetime.date(1959, 4, 7), 'Kazuhisa', 'Ranta', 'M', datetime.date(1997, 4, 29)),
#  (10200, datetime.date(1961, 12, 31), 'Vidya', 'Awdeh', 'M', datetime.date(1985, 10, 16)),
#  (10201, datetime.date(1956, 12, 15), 'Idoia', 'Kavraki', 'F', datetime.date(1986, 11, 22)),
#  (10202, datetime.date(1956, 1, 5), 'Greger', 'Lichtner', 'M', datetime.date(1991, 10, 6)),
#  (10203, datetime.date(1955, 7, 27), 'Steen', 'Escriba', 'M', datetime.date(1989, 4, 6)),
#  (10204, datetime.date(1956, 12, 9), 'Nevio', 'Ritcey', 'F', datetime.date(1986, 12, 4)),
#  (10205, datetime.date(1953, 5, 20), 'Mabhin', 'Leijenhorst', 'F', datetime.date(1993, 8, 23)),
#  (10206, datetime.date(1960, 9, 19), 'Alassane', 'Iwayama', 'F', datetime.date(1988, 4, 19)),
#  (10207, datetime.date(1955, 5, 28), 'Girolamo', 'Anandan', 'F', datetime.date(1992, 10, 11)),
#  (10208, datetime.date(1960, 1, 2), 'Xiping', 'Klerer', 'M', datetime.date(1991, 12, 23)),
#  (10209, datetime.date(1956, 12, 12), 'Yolla', 'Ellozy', 'F', datetime.date(1991, 11, 23)),
#  (10210, datetime.date(1958, 1, 24), 'Yuping', 'Alpin', 'M', datetime.date(1994, 5, 10)),
#  (10211, datetime.date(1964, 8, 5), 'Vishu', 'Strehl', 'F', datetime.date(1989, 11, 18)),
#  (10212, datetime.date(1959, 5, 9), 'Divier', 'Esteva', 'M', datetime.date(1990, 7, 11)),
#  (10213, datetime.date(1964, 5, 24), 'Jackson', 'Kakkad', 'M', datetime.date(1992, 11, 6)),
#  (10214, datetime.date(1962, 4, 14), 'Tadahiko', 'Ciolek', 'M', datetime.date(1988, 2, 29)),
#  (10215, datetime.date(1954, 4, 2), 'Xiaobin', 'Duclos', 'M', datetime.date(1987, 10, 19)),
#  (10216, datetime.date(1958, 7, 16), 'Amstein', 'Ghemri', 'M', datetime.date(1987, 10, 30)),
#  (10217, datetime.date(1954, 7, 7), 'Yongmin', 'Roison', 'F', datetime.date(1986, 5, 12)),
#  (10218, datetime.date(1958, 12, 7), 'Zhenhua', 'Magalhaes', 'M', datetime.date(1997, 1, 15)),
#  (10219, datetime.date(1952, 5, 2), 'Genta', 'Kolvik', 'M', datetime.date(1993, 3, 31)),
#  (10220, datetime.date(1958, 5, 25), 'Kish', 'Fasbender', 'F', datetime.date(1992, 6, 25)),
#  (10221, datetime.date(1957, 1, 3), 'Yucai', 'Granlund', 'M', datetime.date(1988, 6, 8)),
#  (10222, datetime.date(1962, 9, 21), 'Tze', 'Nourani', 'M', datetime.date(1986, 6, 8)),
#  (10223, datetime.date(1963, 9, 17), 'Carrsten', 'Schmiedel', 'F', datetime.date(1985, 11, 18)),
#  (10224, datetime.date(1954, 5, 17), 'Leon', 'Trogemann', 'M', datetime.date(1988, 1, 9)),
#  (10225, datetime.date(1957, 2, 13), 'Kellie', 'Chinen', 'F', datetime.date(1986, 6, 19)),
#  (10226, datetime.date(1964, 12, 28), 'Xinglin', 'Plessier', 'M', datetime.date(1989, 10, 27)),
#  (10227, datetime.date(1957, 7, 4), 'Anneli', 'Kaiser', 'M', datetime.date(1994, 4, 24)),
#  (10228, datetime.date(1953, 4, 21), 'Karoline', 'Cesareni', 'F', datetime.date(1991, 8, 26)),
#  (10229, datetime.date(1952, 2, 10), 'Ulises', 'Takanami', 'M', datetime.date(1987, 11, 22)),
#  (10230, datetime.date(1955, 9, 11), 'Clyde', 'Vernadat', 'M', datetime.date(1996, 6, 16)),
#  (10231, datetime.date(1963, 7, 21), 'Shaowen', 'Desikan', 'F', datetime.date(1996, 4, 13)),
#  (10232, datetime.date(1956, 3, 11), 'Marko', 'Auria', 'F', datetime.date(1992, 6, 4)),
#  (10233, datetime.date(1954, 4, 1), 'Lein', 'Vendrig', 'F', datetime.date(1985, 7, 5)),
#  (10234, datetime.date(1961, 1, 18), 'Arunachalam', 'Bakhtari', 'M', datetime.date(1990, 11, 19)),
#  (10235, datetime.date(1958, 3, 27), 'Susanta', 'Roccetti', 'F', datetime.date(1995, 4, 6)),
#  (10236, datetime.date(1960, 3, 26), 'Susumu', 'Bade', 'F', datetime.date(1996, 8, 30)),
#  (10237, datetime.date(1952, 9, 22), 'Yannis', 'Mandell', 'F', datetime.date(1989, 8, 11)),
#  (10238, datetime.date(1964, 11, 2), 'Mototsugu', 'Gire', 'F', datetime.date(1986, 11, 19)),
#  (10239, datetime.date(1955, 3, 31), 'Nikolaos', 'Llado', 'F', datetime.date(1995, 5, 8)),
#  (10240, datetime.date(1952, 4, 1), 'Remko', 'Maccarone', 'M', datetime.date(1998, 10, 6)),
#  (10241, datetime.date(1958, 7, 1), 'Ortrud', 'Murillo', 'M', datetime.date(1988, 6, 12)),
#  (10242, datetime.date(1964, 2, 22), 'Lunjin', 'Ozeri', 'M', datetime.date(1988, 1, 18)),
#  (10243, datetime.date(1960, 12, 22), 'Wonhee', 'Pouyioutas', 'M', datetime.date(1985, 11, 24)),
#  (10244, datetime.date(1961, 10, 24), 'Foong', 'Flasterstein', 'M', datetime.date(1985, 12, 23)),
#  (10245, datetime.date(1962, 8, 23), 'Ramalingam', 'Gente', 'F', datetime.date(1985, 4, 26)),
#  (10246, datetime.date(1962, 6, 23), 'Basem', 'Teitelbaum', 'M', datetime.date(1987, 7, 12)),
#  (10247, datetime.date(1964, 6, 30), 'Heon', 'Riefers', 'F', datetime.date(1992, 8, 14)),
#  (10248, datetime.date(1955, 9, 24), 'Frederique', 'Tempesti', 'F', datetime.date(1991, 8, 13)),
#  (10249, datetime.date(1954, 6, 10), 'Marie', 'Boreale', 'M', datetime.date(1991, 12, 8)),
#  (10250, datetime.date(1958, 8, 12), 'Serap', 'Etalle', 'M', datetime.date(1992, 8, 30)),
#  (10251, datetime.date(1957, 4, 25), 'Alair', 'Rosenbaum', 'M', datetime.date(1992, 6, 25)),
#  (10252, datetime.date(1961, 1, 30), 'Shirish', 'Wegerle', 'F', datetime.date(1990, 11, 8)),
#  (10253, datetime.date(1964, 11, 12), 'Zsolt', 'Salinas', 'F', datetime.date(1985, 2, 21)),
#  (10254, datetime.date(1959, 12, 7), 'Shen', 'Brattka', 'M', datetime.date(1990, 6, 14)),
#  (10255, datetime.date(1964, 2, 8), 'Roddy', 'Garnick', 'M', datetime.date(1993, 5, 12)),
#  (10256, datetime.date(1960, 12, 2), 'Irene', 'Radhakrishnan', 'M', datetime.date(1985, 10, 12)),
#  (10257, datetime.date(1957, 9, 12), 'Aiman', 'Riexinger', 'M', datetime.date(1986, 8, 5)),
#  (10258, datetime.date(1955, 12, 12), 'Basil', 'Ishibashi', 'F', datetime.date(1985, 5, 17)),
#  (10259, datetime.date(1964, 11, 24), 'Susanna', 'Vesel', 'M', datetime.date(1986, 6, 25)),
#  (10260, datetime.date(1961, 7, 14), 'Alper', 'Suomi', 'F', datetime.date(1991, 4, 13)),
#  (10261, datetime.date(1959, 12, 25), 'Mang', 'Erie', 'M', datetime.date(1993, 10, 20)),
#  (10262, datetime.date(1955, 8, 4), 'Mahendra', 'Maraist', 'F', datetime.date(1992, 7, 27)),
#  (10263, datetime.date(1961, 2, 8), 'Takahiro', 'Waterhouse', 'M', datetime.date(1994, 2, 5)),
#  (10264, datetime.date(1958, 9, 8), 'Nalini', 'Kawashimo', 'F', datetime.date(1997, 7, 16)),
#  (10265, datetime.date(1960, 12, 1), 'Ramalingam', 'Muniz', 'M', datetime.date(1989, 7, 13)),
#  (10266, datetime.date(1958, 2, 24), 'Sukumar', 'Rassart', 'M', datetime.date(1990, 5, 25)),
#  (10267, datetime.date(1956, 1, 16), 'Shaunak', 'Cullers', 'M', datetime.date(1996, 12, 11)),
#  (10268, datetime.date(1958, 6, 3), 'Nishit', 'Siochi', 'M', datetime.date(1986, 12, 17)),
#  (10269, datetime.date(1959, 10, 7), 'Taizo', 'Oxman', 'F', datetime.date(1988, 7, 24)),
#  (10270, datetime.date(1963, 1, 30), 'Bedir', 'Hartvigsen', 'F', datetime.date(1990, 4, 26)),
#  (10271, datetime.date(1962, 4, 24), 'Sham', 'Eastman', 'M', datetime.date(1986, 5, 23)),
#  (10272, datetime.date(1954, 11, 30), 'Yishai', 'Cannane', 'M', datetime.date(1988, 5, 23)),
#  (10273, datetime.date(1962, 8, 29), 'Baocai', 'Lieblein', 'M', datetime.date(1985, 11, 6)),
#  (10274, datetime.date(1957, 8, 23), 'Dmitri', 'Pearson', 'F', datetime.date(1991, 4, 21)),
#  (10275, datetime.date(1961, 10, 22), 'Marek', 'Luck', 'F', datetime.date(1987, 9, 8)),
#  (10276, datetime.date(1964, 7, 27), 'Xuejun', 'Hempstead', 'M', datetime.date(1985, 7, 21)),
#  (10277, datetime.date(1964, 8, 15), 'Isaac', 'Schwartzbauer', 'M', datetime.date(1985, 6, 16)),
#  (10278, datetime.date(1955, 3, 9), 'Lubomir', 'Nitsch', 'M', datetime.date(1991, 5, 17)),
#  (10279, datetime.date(1964, 8, 20), 'Barton', 'Jumpertz', 'F', datetime.date(1994, 12, 20)),
#  (10280, datetime.date(1964, 10, 29), 'Stabislas', 'Delgrange', 'M', datetime.date(1988, 3, 18)),
#  (10281, datetime.date(1953, 5, 13), 'Moty', 'Kusakari', 'M', datetime.date(1994, 12, 3)),
#  (10282, datetime.date(1953, 11, 27), 'Hercules', 'Benzmuller', 'M', datetime.date(1986, 6, 4)),
#  (10283, datetime.date(1953, 7, 8), 'Kauko', 'Birjandi', 'M', datetime.date(1988, 5, 25)),
#  (10284, datetime.date(1954, 4, 8), 'Masali', 'Murrill', 'F', datetime.date(1997, 7, 2)),
#  (10285, datetime.date(1956, 9, 21), 'Zhonghui', 'Preusig', 'F', datetime.date(1995, 2, 27)),
#  (10286, datetime.date(1952, 5, 14), 'Saddek', 'Gopalakrishnan', 'F', datetime.date(1988, 3, 21)),
#  (10287, datetime.date(1963, 11, 28), 'Marie', 'Pietracaprina', 'M', datetime.date(1992, 12, 28)),
#  (10288, datetime.date(1959, 6, 2), 'Selwyn', 'Perri', 'M', datetime.date(1994, 8, 29)),
#  (10289, datetime.date(1956, 11, 30), 'Shay', 'Poulakidas', 'M', datetime.date(1990, 6, 6)),
#  (10290, datetime.date(1957, 5, 29), 'Yongmao', 'Pleszkun', 'M', datetime.date(1991, 9, 18)),
#  (10291, datetime.date(1965, 1, 23), 'Dipayan', 'Seghrouchni', 'M', datetime.date(1986, 9, 29)),
#  (10292, datetime.date(1963, 1, 27), 'Yucel', 'Ghelli', 'F', datetime.date(1989, 6, 5)),
#  (10293, datetime.date(1956, 11, 24), 'Mihalis', 'Avouris', 'F', datetime.date(1992, 12, 12)),
#  (10294, datetime.date(1955, 1, 5), 'Rutger', 'Miara', 'M', datetime.date(1996, 4, 8)),
#  (10295, datetime.date(1953, 1, 13), 'Kristine', 'Velardi', 'M', datetime.date(1990, 8, 27)),
#  (10296, datetime.date(1964, 5, 13), 'Petter', 'Lorho', 'M', datetime.date(1989, 9, 16)),
#  (10297, datetime.date(1956, 6, 17), 'Narain', 'Oaver', 'F', datetime.date(1986, 5, 28)),
#  (10298, datetime.date(1954, 7, 6), 'Dietrich', 'DuCasse', 'F', datetime.date(1999, 3, 30)),
#  (10299, datetime.date(1960, 6, 21), 'Ipke', 'Stentiford', 'F', datetime.date(1990, 1, 10)),
#  (10300, datetime.date(1960, 7, 12), 'Tadahiko', 'Ulupinar', 'F', datetime.date(1991, 5, 17)),
#  (10301, datetime.date(1962, 8, 26), 'Lucien', 'Staudhammer', 'M', datetime.date(1988, 5, 23)),
#  (10302, datetime.date(1954, 10, 11), 'Faiza', 'Baer', 'F', datetime.date(1986, 7, 22)),
#  (10303, datetime.date(1961, 9, 11), 'Marlo', 'Zschoche', 'M', datetime.date(1990, 2, 5)),
#  (10304, datetime.date(1956, 3, 7), 'Bernt', 'Erie', 'M', datetime.date(1992, 11, 16)),
#  (10305, datetime.date(1952, 6, 30), 'Hirochika', 'Piancastelli', 'M', datetime.date(1988, 10, 31)),
#  (10306, datetime.date(1953, 6, 2), 'Heng', 'Kilgour', 'M', datetime.date(1993, 9, 6)),
#  (10307, datetime.date(1955, 7, 20), 'Nikolaos', 'Leaver', 'M', datetime.date(1991, 4, 10)),
#  (10308, datetime.date(1961, 3, 14), 'Dzung', 'Holburn', 'F', datetime.date(1992, 12, 29)),
#  (10309, datetime.date(1964, 11, 6), 'Prodip', 'Schusler', 'F', datetime.date(1985, 6, 20)),
#  (10310, datetime.date(1964, 8, 29), 'Aksel', 'Alencar', 'M', datetime.date(1990, 10, 24)),
#  (10311, datetime.date(1958, 11, 24), 'Hsiangchu', 'Molenkamp', 'F', datetime.date(1991, 4, 1)),
#  (10312, datetime.date(1957, 6, 18), 'Rasiah', 'Deyuan', 'F', datetime.date(1986, 8, 28)),
#  (10313, datetime.date(1962, 5, 30), 'Subbu', 'Riexinger', 'M', datetime.date(1994, 10, 10)),
#  (10314, datetime.date(1961, 5, 4), 'Christfried', 'Apsitis', 'M', datetime.date(1986, 1, 16)),
#  (10315, datetime.date(1956, 8, 3), 'Maris', 'Angelopoulos', 'M', datetime.date(1987, 8, 28)),
#  (10316, datetime.date(1958, 6, 20), 'Christoper', 'Schwaller', 'M', datetime.date(1987, 9, 4)),
#  (10317, datetime.date(1957, 12, 25), 'Arie', 'Birge', 'M', datetime.date(1986, 12, 10)),
#  (10318, datetime.date(1958, 8, 27), 'Mototsugu', 'Beilner', 'F', datetime.date(1985, 6, 29)),
#  (10319, datetime.date(1963, 3, 9), 'Mechthild', 'Miyakawa', 'M', datetime.date(1985, 8, 15)),
#  (10320, datetime.date(1956, 6, 22), 'Uinam', 'Stasinski', 'F', datetime.date(1988, 11, 3)),
#  (10321, datetime.date(1955, 12, 12), 'Guenter', 'Ravishankar', 'M', datetime.date(1991, 9, 24)),
#  (10322, datetime.date(1954, 5, 28), 'Isamu', 'Dahlbom', 'F', datetime.date(1990, 1, 29)),
#  (10323, datetime.date(1958, 6, 20), 'Kankanahalli', 'Hinsberger', 'M', datetime.date(1991, 6, 6)),
#  (10324, datetime.date(1957, 12, 29), 'Bernardo', 'Rouquie', 'F', datetime.date(1988, 3, 19)),
#  (10325, datetime.date(1953, 1, 12), 'Arunachalam', 'Badr', 'M', datetime.date(1990, 9, 20)),
#  (10326, datetime.date(1953, 2, 13), 'Masali', 'Czap', 'F', datetime.date(1985, 5, 13)),
#  (10327, datetime.date(1954, 4, 1), 'Roded', 'Facello', 'M', datetime.date(1987, 9, 18)),
#  (10328, datetime.date(1955, 6, 28), 'Serenella', 'Kawashima', 'M', datetime.date(1994, 1, 16)),
#  (10329, datetime.date(1958, 4, 28), 'Remko', 'Shigei', 'F', datetime.date(1986, 1, 20)),
#  (10330, datetime.date(1957, 2, 2), 'Kasturi', 'Bellmore', 'M', datetime.date(1985, 6, 12)),
#  (10331, datetime.date(1961, 8, 12), 'Arto', 'Binkley', 'M', datetime.date(1985, 4, 6)),
#  (10332, datetime.date(1961, 11, 5), 'Masanao', 'Bain', 'F', datetime.date(1988, 6, 8)),
#  (10333, datetime.date(1953, 4, 27), 'Snehasis', 'Dymetman', 'M', datetime.date(1993, 1, 16)),
#  (10334, datetime.date(1958, 4, 2), 'Falguni', 'Erie', 'M', datetime.date(1996, 12, 28)),
#  (10335, datetime.date(1963, 3, 13), 'Toshimori', 'Bahi', 'F', datetime.date(1992, 4, 6)),
#  (10336, datetime.date(1961, 7, 16), 'Goa', 'Rothe', 'F', datetime.date(1992, 1, 7)),
#  (10337, datetime.date(1957, 12, 10), 'Jeong', 'Sadowsky', 'M', datetime.date(1995, 8, 6)),
#  (10338, datetime.date(1961, 2, 12), 'Heon', 'Ranai', 'M', datetime.date(1988, 9, 1)),
#  (10339, datetime.date(1957, 8, 27), 'Teunis', 'Liedekerke', 'M', datetime.date(1989, 11, 30)),
#  (10340, datetime.date(1952, 8, 20), 'Djelloul', 'Laventhal', 'M', datetime.date(1987, 6, 5)),
#  (10341, datetime.date(1960, 11, 22), 'Wilmer', 'Greenaway', 'F', datetime.date(1987, 4, 29)),
#  (10342, datetime.date(1960, 3, 17), 'Stella', 'Hiroyama', 'F', datetime.date(1987, 7, 25)),
#  (10343, datetime.date(1954, 11, 1), 'Dinah', 'Syrzycki', 'M', datetime.date(1993, 10, 14)),
#  (10344, datetime.date(1957, 7, 24), 'Uwe', 'Garnier', 'F', datetime.date(1994, 6, 25)),
#  (10345, datetime.date(1960, 12, 13), 'Arra', 'Ratnakar', 'M', datetime.date(1993, 11, 8)),
#  (10346, datetime.date(1963, 1, 29), 'Aamod', 'Radwan', 'M', datetime.date(1987, 1, 27)),
#  (10347, datetime.date(1953, 10, 3), 'Pradeep', 'Kaminger', 'M', datetime.date(1985, 12, 12)),
#  (10348, datetime.date(1956, 3, 11), 'Mahendra', 'Picco', 'F', datetime.date(1995, 10, 22)),
#  (10349, datetime.date(1954, 4, 29), 'Oksana', 'Brodie', 'F', datetime.date(1991, 9, 28)),
#  (10350, datetime.date(1954, 11, 14), 'Kristen', 'Kavvadias', 'F', datetime.date(1990, 8, 19)),
#  (10351, datetime.date(1963, 8, 23), 'Tadahiko', 'Strehl', 'F', datetime.date(1985, 3, 7)),
#  (10352, datetime.date(1960, 1, 28), 'Erzsebet', 'Ohori', 'M', datetime.date(1996, 1, 21)),
#  (10353, datetime.date(1953, 1, 15), 'Phule', 'Hammerschmidt', 'M', datetime.date(1989, 8, 24)),
#  (10354, datetime.date(1961, 4, 21), 'Moto', 'Kusakari', 'M', datetime.date(1996, 3, 26)),
#  (10355, datetime.date(1952, 12, 10), 'Satyanarayana', 'Cochrane', 'M', datetime.date(1987, 11, 15)),
#  (10356, datetime.date(1952, 8, 12), 'Vasilis', 'Standera', 'M', datetime.date(1988, 8, 6)),
#  (10357, datetime.date(1964, 1, 10), 'Hausi', 'Sidhu', 'M', datetime.date(1994, 4, 4)),
#  (10358, datetime.date(1953, 4, 8), 'Qunsheng', 'Tagansky', 'M', datetime.date(1991, 2, 19)),
#  (10359, datetime.date(1960, 4, 18), 'Heekeun', 'Sambasivam', 'F', datetime.date(1991, 5, 9)),
#  (10360, datetime.date(1960, 11, 4), 'Irene', 'Munck', 'M', datetime.date(1996, 9, 4)),
#  (10361, datetime.date(1961, 4, 22), 'Seshu', 'Sidou', 'F', datetime.date(1986, 10, 23)),
#  (10362, datetime.date(1963, 9, 16), 'Shalesh', 'dAstous', 'M', datetime.date(1988, 8, 24)),
#  (10363, datetime.date(1953, 11, 28), 'Toshiki', 'Muniz', 'F', datetime.date(1985, 9, 11)),
#  (10364, datetime.date(1954, 9, 21), 'Nakhoon', 'Dengi', 'M', datetime.date(1985, 11, 14)),
#  (10365, datetime.date(1958, 4, 28), 'Rosine', 'Granlund', 'F', datetime.date(1987, 6, 2)),
#  (10366, datetime.date(1960, 1, 25), 'Morrie', 'Piazza', 'M', datetime.date(1994, 4, 11)),
#  (10367, datetime.date(1955, 12, 24), 'Hyuckchul', 'Gini', 'M', datetime.date(1991, 6, 24)),
#  (10368, datetime.date(1956, 3, 25), 'Hatim', 'Koshiba', 'M', datetime.date(1991, 4, 5)),
#  (10369, datetime.date(1957, 1, 8), 'Qunsheng', 'Toyoshima', 'M', datetime.date(1986, 5, 17)),
#  (10370, datetime.date(1957, 8, 3), 'Clyde', 'Fandrianto', 'M', datetime.date(1992, 4, 4)),
#  (10371, datetime.date(1959, 2, 10), 'Ioana', 'Kirkerud', 'M', datetime.date(1989, 11, 28)),
#  (10372, datetime.date(1952, 4, 8), 'Anneli', 'Frijda', 'F', datetime.date(1985, 7, 30)),
#  (10373, datetime.date(1959, 1, 8), 'Hongzue', 'Heijenga', 'M', datetime.date(1997, 4, 26)),
#  (10374, datetime.date(1955, 10, 8), 'Willard', 'Rosin', 'F', datetime.date(1993, 12, 8)),
#  (10375, datetime.date(1957, 10, 9), 'Dante', 'Kalafatis', 'F', datetime.date(1994, 5, 29)),
#  (10376, datetime.date(1959, 2, 12), 'Fai', 'Bale', 'M', datetime.date(1989, 1, 14)),
#  (10377, datetime.date(1954, 8, 19), 'Marl', 'Grospietsch', 'M', datetime.date(1990, 5, 7)),
#  (10378, datetime.date(1964, 9, 5), 'Takahira', 'Lichtner', 'M', datetime.date(1990, 12, 30)),
#  (10379, datetime.date(1957, 3, 2), 'Mikhail', 'Rosis', 'M', datetime.date(1996, 7, 15)),
#  (10380, datetime.date(1956, 5, 25), 'Alejandro', 'Kamble', 'F', datetime.date(1985, 3, 19)),
#  (10381, datetime.date(1963, 3, 4), 'Jiong', 'Parfitt', 'M', datetime.date(1991, 12, 4)),
#  (10382, datetime.date(1955, 6, 12), 'Shirish', 'Dredge', 'M', datetime.date(1990, 7, 4)),
#  (10383, datetime.date(1963, 11, 13), 'Leucio', 'Aumann', 'M', datetime.date(1991, 6, 19)),
#  (10384, datetime.date(1956, 8, 22), 'Feiyu', 'Luft', 'M', datetime.date(1986, 1, 16)),
#  (10385, datetime.date(1963, 5, 14), 'Khatoun', 'Imataki', 'M', datetime.date(1992, 12, 20)),
#  (10386, datetime.date(1956, 11, 9), 'Eishiro', 'Miyakawa', 'F', datetime.date(1985, 8, 2)),
#  (10387, datetime.date(1952, 11, 3), 'Parto', 'Wrigley', 'F', datetime.date(1987, 2, 19)),
#  (10388, datetime.date(1953, 3, 29), 'Hironoby', 'Kaiser', 'M', datetime.date(1996, 3, 24)),
#  (10389, datetime.date(1953, 3, 24), 'Make', 'Peir', 'M', datetime.date(1995, 10, 31)),
#  (10390, datetime.date(1960, 3, 7), 'Wanqing', 'Bratten', 'M', datetime.date(1989, 5, 17)),
#  (10391, datetime.date(1956, 6, 13), 'Hongzue', 'Akaboshi', 'M', datetime.date(1989, 12, 24)),
#  (10392, datetime.date(1962, 2, 17), 'Jiann', 'Hainaut', 'M', datetime.date(1992, 3, 1)),
#  (10393, datetime.date(1958, 3, 24), 'Yagil', 'DasSarma', 'M', datetime.date(1989, 6, 23)),
#  (10394, datetime.date(1957, 5, 22), 'Shawna', 'Meriste', 'M', datetime.date(1991, 3, 14)),
#  (10395, datetime.date(1952, 2, 17), 'Takahiro', 'Deverell', 'M', datetime.date(1987, 2, 4)),
#  (10396, datetime.date(1955, 8, 21), 'Sibyl', 'Rahier', 'M', datetime.date(1986, 1, 11)),
#  (10397, datetime.date(1955, 11, 11), 'Irena', 'Reutenauer', 'M', datetime.date(1993, 5, 21)),
#  (10398, datetime.date(1958, 7, 16), 'Shooichi', 'Escriba', 'F', datetime.date(1990, 10, 12)),
#  (10399, datetime.date(1957, 6, 13), 'Guenter', 'Marchegay', 'F', datetime.date(1985, 5, 7)),
#  (10400, datetime.date(1961, 12, 16), 'Ortrud', 'Nitto', 'M', datetime.date(1993, 10, 17)),
#  (10401, datetime.date(1962, 4, 25), 'Eckart', 'Barriga', 'M', datetime.date(1991, 4, 5)),
#  (10402, datetime.date(1953, 7, 23), 'Volkmar', 'Ebeling', 'M', datetime.date(1987, 1, 2)),
#  (10403, datetime.date(1956, 4, 1), 'Atreyi', 'Mungall', 'F', datetime.date(1991, 9, 13)),
#  (10404, datetime.date(1955, 4, 27), 'Prodip', 'Rosti', 'F', datetime.date(1988, 8, 28)),
#  (10405, datetime.date(1957, 1, 20), 'Hilary', 'Budinsky', 'F', datetime.date(1985, 11, 4)),
#  (10406, datetime.date(1956, 9, 21), 'Sigeru', 'Wynblatt', 'F', datetime.date(1987, 3, 11)),
#  (10407, datetime.date(1955, 7, 5), 'Ulf', 'Siepmann', 'M', datetime.date(1990, 3, 8)),
#  (10408, datetime.date(1964, 3, 17), 'Martijn', 'Kaiser', 'M', datetime.date(1998, 10, 7)),
#  (10409, datetime.date(1958, 8, 28), 'Mario', 'Straney', 'M', datetime.date(1997, 7, 9)),
#  (10410, datetime.date(1965, 1, 19), 'Takahito', 'Gecsei', 'F', datetime.date(1993, 10, 16)),
#  (10411, datetime.date(1956, 7, 10), 'Lidong', 'Klerer', 'F', datetime.date(1989, 9, 2)),
#  (10412, datetime.date(1958, 2, 26), 'Masoud', 'Fabrizio', 'F', datetime.date(1986, 5, 6)),
#  (10413, datetime.date(1952, 5, 5), 'Danel', 'Impagliazzo', 'F', datetime.date(1990, 3, 26)),
#  (10414, datetime.date(1954, 4, 9), 'Yinlin', 'Alpin', 'M', datetime.date(1990, 5, 30)),
#  (10415, datetime.date(1957, 11, 12), 'Mark', 'Coorg', 'M', datetime.date(1993, 10, 25)),
#  (10416, datetime.date(1956, 5, 26), 'Uli', 'Keustermans', 'M', datetime.date(1989, 3, 24)),
#  (10417, datetime.date(1964, 2, 2), 'Bingning', 'Bakhtari', 'M', datetime.date(1992, 3, 12)),
#  (10418, datetime.date(1952, 6, 29), 'Candida', 'Porotnikoff', 'F', datetime.date(1989, 4, 20)),
#  (10419, datetime.date(1964, 6, 22), 'Maria', 'Bauknecht', 'F', datetime.date(1992, 4, 25)),
#  (10420, datetime.date(1963, 3, 3), 'Kaijung', 'Riesenhuber', 'M', datetime.date(1988, 1, 17)),
#  (10421, datetime.date(1959, 3, 22), 'Divine', 'Marzano', 'M', datetime.date(1989, 9, 12)),
#  (10422, datetime.date(1954, 6, 2), 'Greger', 'Rubsam', 'F', datetime.date(1990, 12, 7)),
#  (10423, datetime.date(1956, 1, 10), 'Dante', 'Cronin', 'F', datetime.date(1998, 9, 6)),
#  (10424, datetime.date(1959, 8, 17), 'Babette', 'Straney', 'M', datetime.date(1989, 8, 7)),
#  (10425, datetime.date(1963, 10, 24), 'Sashi', 'Osgood', 'M', datetime.date(1991, 10, 29)),
#  (10426, datetime.date(1955, 12, 28), 'Arunas', 'Luce', 'F', datetime.date(1985, 7, 6)),
#  (10427, datetime.date(1958, 8, 13), 'Khosrow', 'Sudbeck', 'F', datetime.date(1991, 11, 1)),
#  (10428, datetime.date(1957, 6, 25), 'Cathie', 'Brlek', 'M', datetime.date(1992, 6, 4)),
#  (10429, datetime.date(1952, 2, 13), 'Martien', 'Improta', 'F', datetime.date(1986, 3, 9)),
#  (10430, datetime.date(1958, 6, 30), 'Ferdinand', 'Chenney', 'M', datetime.date(1990, 11, 16)),
#  (10431, datetime.date(1961, 5, 25), 'Patricio', 'Bugrara', 'M', datetime.date(1987, 10, 8)),
#  (10432, datetime.date(1953, 11, 6), 'Hisao', 'Tiemann', 'F', datetime.date(1985, 4, 30)),
#  (10433, datetime.date(1954, 9, 2), 'Reuven', 'Dengi', 'M', datetime.date(1989, 2, 14)),
#  (10434, datetime.date(1959, 7, 17), 'Dzung', 'Peltason', 'F', datetime.date(1995, 6, 27)),
#  (10435, datetime.date(1957, 10, 12), 'Marsha', 'Tagansky', 'M', datetime.date(1986, 12, 19)),
#  (10436, datetime.date(1963, 6, 17), 'Yahiko', 'Lammel', 'M', datetime.date(1988, 1, 30)),
#  (10437, datetime.date(1956, 7, 7), 'Narain', 'Reeker', 'F', datetime.date(1996, 4, 12)),
#  (10438, datetime.date(1961, 12, 25), 'Evgueni', 'Srimani', 'F', datetime.date(1990, 1, 19)),
#  (10439, datetime.date(1958, 4, 9), 'Jolita', 'Jarecki', 'M', datetime.date(1990, 1, 11)),
#  (10440, datetime.date(1959, 4, 10), 'Akeel', 'Narahara', 'F', datetime.date(1994, 3, 31)),
#  (10441, datetime.date(1958, 4, 27), 'Adel', 'Perfilyeva', 'M', datetime.date(1988, 7, 12)),
#  (10442, datetime.date(1955, 9, 9), 'Volkmar', 'Unno', 'M', datetime.date(1988, 3, 13)),
#  (10443, datetime.date(1952, 12, 3), 'Shichao', 'Litvinov', 'F', datetime.date(1989, 8, 1)),
#  (10444, datetime.date(1956, 7, 29), 'Kazuhira', 'Rosis', 'M', datetime.date(1993, 3, 31)),
#  (10445, datetime.date(1957, 1, 10), 'Junichi', 'Kavanagh', 'F', datetime.date(1987, 11, 4)),
#  (10446, datetime.date(1960, 2, 8), 'Ebru', 'Chepyzhov', 'F', datetime.date(1994, 11, 17)),
#  (10447, datetime.date(1962, 10, 24), 'Ronghao', 'Yavatkar', 'F', datetime.date(1988, 12, 29)),
#  (10448, datetime.date(1963, 12, 10), 'Phule', 'Oxenboll', 'F', datetime.date(1992, 3, 12)),
#  (10449, datetime.date(1959, 9, 28), 'Aleksandar', 'Sudkamp', 'M', datetime.date(1987, 3, 28)),
#  (10450, datetime.date(1959, 11, 5), 'Khun', 'Harbusch', 'M', datetime.date(1990, 1, 17)),
#  (10451, datetime.date(1952, 10, 6), 'Bodh', 'Ranta', 'F', datetime.date(1988, 3, 12)),
#  (10452, datetime.date(1956, 11, 24), 'Werner', 'Hasham', 'M', datetime.date(1988, 9, 5)),
#  (10453, datetime.date(1953, 7, 19), 'Tsvetan', 'Matzel', 'F', datetime.date(1985, 4, 2)),
#  (10454, datetime.date(1961, 1, 22), 'Wonhee', 'Badr', 'M', datetime.date(1987, 4, 10)),
#  (10455, datetime.date(1963, 12, 17), 'Sverrir', 'Streng', 'F', datetime.date(1989, 2, 14)),
#  (10456, datetime.date(1963, 1, 24), 'Stepehn', 'Hardjono', 'F', datetime.date(1995, 12, 25)),
#  (10457, datetime.date(1963, 11, 10), 'Oddvar', 'Schlenzig', 'M', datetime.date(1991, 11, 23)),
#  (10458, datetime.date(1961, 1, 6), 'Gina', 'Engelmann', 'F', datetime.date(1988, 7, 23)),
#  (10459, datetime.date(1959, 9, 30), 'Ennio', 'Trogemann', 'M', datetime.date(1997, 6, 28)),
#  (10460, datetime.date(1963, 2, 19), 'Shushma', 'VanScheik', 'M', datetime.date(1994, 7, 1)),
#  (10461, datetime.date(1956, 10, 26), 'Gal', 'Karcich', 'M', datetime.date(1987, 8, 3)),
#  (10462, datetime.date(1956, 4, 8), 'Sumali', 'Schlenzig', 'M', datetime.date(1996, 3, 25)),
#  (10463, datetime.date(1954, 5, 20), 'Ung', 'Zaiane', 'M', datetime.date(1987, 12, 25)),
#  (10464, datetime.date(1962, 9, 4), 'Mang', 'Maginnis', 'F', datetime.date(1989, 10, 9)),
#  (10465, datetime.date(1963, 3, 13), 'Claudi', 'Shackel', 'M', datetime.date(1987, 9, 1)),
#  (10466, datetime.date(1954, 12, 25), 'Jiakeng', 'Himler', 'M', datetime.date(1985, 9, 29)),
#  (10467, datetime.date(1956, 1, 30), 'Dipayan', 'Suomi', 'F', datetime.date(1988, 7, 14)),
#  (10468, datetime.date(1960, 8, 28), 'Yoshimitsu', 'Shobatake', 'M', datetime.date(1991, 5, 28)),
#  (10469, datetime.date(1964, 12, 22), 'Munehiko', 'Ananiadou', 'M', datetime.date(1985, 6, 5)),
#  (10470, datetime.date(1956, 4, 12), 'Peternela', 'Iwayama', 'M', datetime.date(1988, 6, 1)),
#  (10471, datetime.date(1963, 11, 30), 'Jouko', 'Yamaashi', 'M', datetime.date(1990, 11, 18)),
#  (10472, datetime.date(1959, 8, 20), 'Salvador', 'Lodder', 'M', datetime.date(1996, 7, 29)),
#  (10473, datetime.date(1963, 10, 13), 'Przemyslawa', 'Oskamp', 'M', datetime.date(1987, 10, 30)),
#  (10474, datetime.date(1962, 2, 24), 'Kenton', 'Garnham', 'F', datetime.date(1985, 9, 28)),
#  (10475, datetime.date(1956, 12, 19), 'Mario', 'Rodite', 'M', datetime.date(1987, 1, 19)),
#  (10476, datetime.date(1965, 1, 1), 'Kokou', 'Iisaka', 'M', datetime.date(1987, 9, 20)),
#  (10477, datetime.date(1952, 12, 7), 'Guoxiang', 'Trogemann', 'F', datetime.date(1989, 3, 4)),
#  (10478, datetime.date(1957, 3, 8), 'Maik', 'Ushiama', 'M', datetime.date(1992, 6, 9)),
#  (10479, datetime.date(1959, 1, 27), 'Duro', 'Coney', 'F', datetime.date(1987, 2, 28)),
#  (10480, datetime.date(1965, 1, 25), 'Make', 'Baba', 'F', datetime.date(1988, 5, 18)),
#  (10481, datetime.date(1959, 10, 18), 'Yongmao', 'Pintelas', 'F', datetime.date(1988, 10, 6)),
#  (10482, datetime.date(1961, 7, 17), 'Goa', 'Pleszkun', 'F', datetime.date(1991, 7, 20)),
#  (10483, datetime.date(1957, 3, 13), 'Zhiwei', 'Anick', 'M', datetime.date(1992, 11, 8)),
#  (10484, datetime.date(1961, 8, 30), 'Nirmal', 'Varley', 'F', datetime.date(1995, 10, 31)),
#  (10485, datetime.date(1961, 9, 20), 'Teruyuki', 'Sundgren', 'M', datetime.date(1985, 10, 27)),
#  (10486, datetime.date(1952, 8, 24), 'Amstein', 'Kossowski', 'F', datetime.date(1987, 10, 8)),
#  (10487, datetime.date(1956, 8, 23), 'Perla', 'Middleton', 'F', datetime.date(1992, 8, 14)),
#  (10488, datetime.date(1959, 10, 17), 'Mihalis', 'Heering', 'M', datetime.date(1994, 6, 9)),
#  (10489, datetime.date(1958, 8, 24), 'Elvia', 'Homond', 'M', datetime.date(1989, 9, 10)),
#  (10490, datetime.date(1961, 9, 28), 'Huiqun', 'Vuskovic', 'F', datetime.date(1992, 10, 7)),
#  (10491, datetime.date(1964, 9, 9), 'Garnik', 'Narahari', 'M', datetime.date(1990, 1, 17)),
#  (10492, datetime.date(1957, 4, 3), 'Lobel', 'Kumaresan', 'M', datetime.date(1988, 4, 24)),
#  (10493, datetime.date(1962, 1, 12), 'Maris', 'Haraldson', 'M', datetime.date(1992, 5, 16)),
#  (10494, datetime.date(1953, 12, 21), 'Yakkov', 'Servieres', 'F', datetime.date(1986, 1, 18)),
#  (10495, datetime.date(1961, 5, 24), 'Anyuan', 'Zhiwei', 'F', datetime.date(1985, 9, 29)),
#  (10496, datetime.date(1959, 4, 18), 'Gretta', 'Baig', 'M', datetime.date(1987, 2, 26)),
#  (10497, datetime.date(1953, 6, 9), 'Pramod', 'Rabehasaina', 'M', datetime.date(1992, 1, 22)),
#  (10498, datetime.date(1964, 9, 15), 'Valter', 'Cappelletti', 'F', datetime.date(1988, 2, 1)),
#  (10499, datetime.date(1953, 10, 4), 'Maik', 'Luft', 'F', datetime.date(1989, 11, 23)),
#  (10500, datetime.date(1957, 4, 29), 'Vojin', 'Narwekar', 'M', datetime.date(1996, 12, 16)),
#  (10501, datetime.date(1962, 9, 9), 'Susuma', 'Larfeldt', 'M', datetime.date(1987, 4, 20)),
#  (10502, datetime.date(1957, 10, 7), 'Yonghoan', 'Marshall', 'M', datetime.date(1993, 3, 4)),
#  (10503, datetime.date(1952, 5, 17), 'Dannz', 'Pell', 'M', datetime.date(1991, 4, 30)),
#  (10504, datetime.date(1953, 4, 7), 'Xiong', 'Varker', 'M', datetime.date(1988, 12, 3)),
#  (10505, datetime.date(1964, 2, 4), 'Isamu', 'Auria', 'M', datetime.date(1985, 7, 23)),
#  (10506, datetime.date(1958, 10, 6), 'Kazuhisa', 'Kroll', 'F', datetime.date(1996, 12, 1)),
#  (10507, datetime.date(1964, 2, 18), 'Kasidit', 'Belinskaya', 'M', datetime.date(1985, 4, 26)),
#  (10508, datetime.date(1962, 6, 2), 'Kotesh', 'Liedekerke', 'M', datetime.date(1991, 5, 1)),
#  (10509, datetime.date(1953, 10, 3), 'Abdelwaheb', 'Riesenhuber', 'F', datetime.date(1990, 2, 23)),
#  (10510, datetime.date(1960, 2, 13), 'Keung', 'Slobodova', 'F', datetime.date(1990, 4, 20)),
#  (10511, datetime.date(1963, 6, 18), 'Khoa', 'Marrevee', 'M', datetime.date(1992, 1, 27)),
#  (10512, datetime.date(1955, 11, 16), 'Udi', 'Gihr', 'M', datetime.date(1986, 1, 12)),
#  (10513, datetime.date(1959, 7, 7), 'Yuichiro', 'Schicker', 'F', datetime.date(1991, 4, 2)),
#  (10514, datetime.date(1963, 4, 3), 'Tomofumi', 'McClure', 'M', datetime.date(1992, 4, 29)),
#  (10515, datetime.date(1963, 12, 15), 'Raimond', 'Kirkerud', 'M', datetime.date(1989, 10, 28)),
#  (10516, datetime.date(1960, 2, 20), 'Xiadong', 'Luga', 'M', datetime.date(1985, 10, 19)),
#  (10517, datetime.date(1953, 6, 18), 'Tiina', 'Speek', 'M', datetime.date(1990, 12, 25)),
#  (10518, datetime.date(1963, 5, 23), 'Marin', 'Lanphier', 'M', datetime.date(1993, 9, 3)),
# ...
#  (10829, datetime.date(1955, 7, 11), 'Alper', 'Narahara', 'F', datetime.date(1993, 2, 22)),
#  (10830, datetime.date(1954, 8, 17), 'Fen', 'Fiebach', 'M', datetime.date(1991, 8, 24)),
#  (10831, datetime.date(1953, 10, 11), 'Toong', 'Driscoll', 'M', datetime.date(1996, 6, 21)),
#  (10832, datetime.date(1964, 8, 29), 'Hidde', 'Bergere', 'F', datetime.date(1986, 10, 11)),
#  (10833, datetime.date(1953, 4, 12), 'Krisda', 'Gecseg', 'F', datetime.date(1989, 2, 8)),
#  (10834, datetime.date(1954, 12, 16), 'Huiqun', 'Rajcani', 'M', datetime.date(1990, 11, 24)),
#  (10835, datetime.date(1952, 11, 23), 'Tomoyuki', 'Kermarrec', 'M', datetime.date(1985, 7, 28)),
#  (10836, datetime.date(1953, 7, 15), 'Jianhua', 'Leivant', 'F', datetime.date(1985, 7, 26)),
#  (10837, datetime.date(1957, 2, 6), 'Chuanti', 'Karlin', 'M', datetime.date(1986, 1, 14)),
#  (10838, datetime.date(1957, 10, 19), 'Deniz', 'Ramras', 'M', datetime.date(1990, 4, 11)),
#  (10839, datetime.date(1964, 4, 2), 'Gurbir', 'Katiyar', 'M', datetime.date(1991, 10, 5)),
#  (10840, datetime.date(1961, 4, 26), 'Mohammad', 'Koshino', 'M', datetime.date(1993, 6, 4)),
#  (10841, datetime.date(1961, 10, 14), 'Pranav', 'Lieberherr', 'M', datetime.date(1990, 4, 21)),
#  (10842, datetime.date(1961, 8, 29), 'Berni', 'Sanella', 'F', datetime.date(1986, 7, 14)),
#  (10843, datetime.date(1961, 9, 5), 'Honesty', 'Smeets', 'M', datetime.date(1990, 4, 26)),
#  (10844, datetime.date(1954, 2, 3), 'Dipayan', 'Koprowski', 'M', datetime.date(1987, 3, 3)),
#  (10845, datetime.date(1960, 12, 24), 'Hidde', 'Tasistro', 'F', datetime.date(1988, 6, 30)),
#  (10846, datetime.date(1952, 6, 27), 'Tokuyasu', 'Serre', 'M', datetime.date(1994, 1, 26)),
#  (10847, datetime.date(1952, 3, 4), 'Theirry', 'Danley', 'M', datetime.date(1986, 7, 25)),
#  (10848, datetime.date(1954, 7, 16), 'Fen', 'Bratsberg', 'F', datetime.date(1985, 4, 20)),
#  (10849, datetime.date(1953, 3, 5), 'Makato', 'Mayerwieser', 'M', datetime.date(1995, 6, 25)),
#  (10850, datetime.date(1963, 1, 1), 'Florina', 'Schapire', 'F', datetime.date(1990, 4, 22)),
#  (10851, datetime.date(1959, 11, 15), 'Piyawadee', 'Copas', 'M', datetime.date(1994, 11, 21)),
#  (10852, datetime.date(1959, 11, 24), 'Hercules', 'Munck', 'F', datetime.date(1996, 3, 21)),
#  (10853, datetime.date(1964, 3, 22), 'Yoshinari', 'Kalloufi', 'F', datetime.date(1993, 5, 3)),
#  (10854, datetime.date(1954, 8, 11), 'Jagoda', 'Nannarelli', 'M', datetime.date(1998, 7, 13)),
#  (10855, datetime.date(1957, 8, 7), 'Kwangho', 'Reinhart', 'M', datetime.date(1991, 8, 5)),
#  (10856, datetime.date(1964, 3, 13), 'Sreenivas', 'Peck', 'F', datetime.date(1986, 12, 31)),
#  (10857, datetime.date(1957, 6, 11), 'Fusako', 'Stenning', 'F', datetime.date(1990, 4, 4)),
#  (10858, datetime.date(1952, 10, 1), 'Kenroku', 'Gonthier', 'M', datetime.date(1996, 8, 15)),
#  (10859, datetime.date(1961, 10, 16), 'King', 'Bernini', 'F', datetime.date(1993, 1, 3)),
#  (10860, datetime.date(1961, 11, 5), 'Gino', 'Werthner', 'M', datetime.date(1992, 3, 11)),
#  (10861, datetime.date(1962, 2, 27), 'Howell', 'Baek', 'M', datetime.date(1989, 6, 10)),
#  (10862, datetime.date(1956, 1, 19), 'Zhenbing', 'Kadhim', 'F', datetime.date(1985, 7, 23)),
#  (10863, datetime.date(1962, 8, 5), 'Byong', 'Bhattacharjee', 'M', datetime.date(1985, 12, 25)),
#  (10864, datetime.date(1958, 1, 7), 'Elliott', 'Spieker', 'F', datetime.date(1985, 9, 4)),
#  (10865, datetime.date(1961, 3, 16), 'Danco', 'Etalle', 'M', datetime.date(1991, 4, 19)),
#  (10866, datetime.date(1959, 12, 13), 'Fayez', 'Yeung', 'F', datetime.date(1990, 12, 27)),
#  (10867, datetime.date(1952, 10, 1), 'Billur', 'Gyorkos', 'M', datetime.date(1986, 10, 8)),
#  (10868, datetime.date(1959, 5, 11), 'Houman', 'Unno', 'F', datetime.date(1990, 3, 20)),
#  (10869, datetime.date(1962, 10, 9), 'Guangming', 'Jonsson', 'F', datetime.date(1996, 3, 15)),
#  (10870, datetime.date(1956, 7, 23), 'Shahid', 'Leppanen', 'F', datetime.date(1988, 1, 13)),
#  (10871, datetime.date(1952, 10, 24), 'Aram', 'Gilg', 'M', datetime.date(1989, 2, 15)),
#  (10872, datetime.date(1952, 2, 21), 'Karoline', 'Speel', 'F', datetime.date(1990, 9, 6)),
#  (10873, datetime.date(1952, 7, 9), 'Sukumar', 'Wegerle', 'M', datetime.date(1994, 3, 23)),
#  (10874, datetime.date(1958, 1, 18), 'Mahmut', 'Borstler', 'M', datetime.date(1986, 4, 22)),
#  (10875, datetime.date(1958, 10, 27), 'Filipp', 'Suri', 'F', datetime.date(1988, 5, 19)),
#  (10876, datetime.date(1955, 8, 5), 'Vincent', 'Papastamatiou', 'F', datetime.date(1995, 1, 29)),
#  (10877, datetime.date(1964, 9, 11), 'Subir', 'Biron', 'M', datetime.date(1986, 6, 6)),
#  (10878, datetime.date(1952, 6, 13), 'Lakshmi', 'Deville', 'M', datetime.date(1988, 2, 25)),
#  (10879, datetime.date(1953, 8, 18), 'Muzhong', 'Chleq', 'F', datetime.date(1985, 8, 15)),
#  (10880, datetime.date(1962, 2, 11), 'Weiye', 'Nitsche', 'M', datetime.date(1986, 4, 20)),
#  (10881, datetime.date(1959, 6, 13), 'Katsuo', 'Miake', 'M', datetime.date(1996, 4, 18)),
#  (10882, datetime.date(1953, 11, 1), 'Fun', 'Heuser', 'M', datetime.date(1994, 11, 29)),
#  (10883, datetime.date(1952, 7, 30), 'Shimshon', 'Champarnaud', 'M', datetime.date(1987, 11, 7)),
#  (10884, datetime.date(1958, 3, 7), 'Teunis', 'Kleiser', 'F', datetime.date(1993, 4, 15)),
#  (10885, datetime.date(1953, 5, 6), 'Rayond', 'Cronau', 'M', datetime.date(1991, 8, 19)),
#  (10886, datetime.date(1964, 9, 30), 'Sushant', 'Begiun', 'M', datetime.date(1995, 3, 26)),
#  (10887, datetime.date(1953, 1, 16), 'Lunjin', 'DeMori', 'M', datetime.date(1989, 3, 16)),
#  (10888, datetime.date(1959, 3, 15), 'Kwangho', 'Dredge', 'F', datetime.date(1987, 6, 28)),
#  (10889, datetime.date(1956, 6, 21), 'Cheong', 'Coors', 'F', datetime.date(1987, 8, 11)),
#  (10890, datetime.date(1963, 4, 13), 'Ramzi', 'Furudate', 'M', datetime.date(1988, 4, 21)),
#  (10891, datetime.date(1963, 12, 15), 'Susanne', 'Jiang', 'F', datetime.date(1990, 12, 7)),
#  (10892, datetime.date(1959, 12, 13), 'Kazunori', 'Vieth', 'M', datetime.date(1990, 4, 11)),
#  (10893, datetime.date(1960, 1, 30), 'Danil', 'Kropatsch', 'M', datetime.date(1989, 8, 23)),
#  (10894, datetime.date(1958, 8, 21), 'Suebskul', 'Srimani', 'F', datetime.date(1991, 7, 18)),
#  (10895, datetime.date(1952, 3, 21), 'Vishwani', 'Petersohn', 'M', datetime.date(1986, 4, 26)),
#  (10896, datetime.date(1964, 4, 12), 'Adil', 'Taubenfeld', 'M', datetime.date(1994, 10, 8)),
#  (10897, datetime.date(1958, 5, 27), 'Arno', 'Kumaresan', 'F', datetime.date(1986, 4, 9)),
#  (10898, datetime.date(1961, 11, 10), 'Munenori', 'Markovitch', 'F', datetime.date(1986, 4, 10)),
#  (10899, datetime.date(1962, 5, 11), 'Valery', 'Rousseau', 'F', datetime.date(1989, 10, 6)),
#  (10900, datetime.date(1955, 7, 18), 'Ferdinand', 'Prenel', 'F', datetime.date(1995, 9, 7)),
#  (10901, datetime.date(1959, 6, 12), 'Chrisa', 'Narahara', 'M', datetime.date(1992, 10, 30)),
#  (10902, datetime.date(1964, 5, 9), 'Inderjeet', 'Perly', 'M', datetime.date(1990, 4, 22)),
#  (10903, datetime.date(1958, 6, 4), 'Visit', 'Nyanchama', 'M', datetime.date(1989, 2, 14)),
#  (10904, datetime.date(1959, 8, 28), 'Debatosh', 'Colorni', 'F', datetime.date(1993, 4, 16)),
#  (10905, datetime.date(1961, 4, 30), 'Jianhui', 'Aloia', 'M', datetime.date(1985, 2, 28)),
#  (10906, datetime.date(1952, 2, 6), 'Munehiro', 'Carrere', 'F', datetime.date(1994, 1, 20)),
#  (10907, datetime.date(1963, 9, 26), 'JiYoung', 'Luks', 'M', datetime.date(1988, 12, 25)),
#  (10908, datetime.date(1961, 11, 27), 'Rajmohan', 'Koblick', 'M', datetime.date(1985, 10, 8)),
#  (10909, datetime.date(1954, 11, 11), 'Georgi', 'Atchley', 'M', datetime.date(1985, 4, 21)),
#  (10910, datetime.date(1958, 11, 11), 'Arco', 'Jervis', 'M', datetime.date(1989, 7, 13)),
#  (10911, datetime.date(1959, 7, 22), 'Shay', 'Casley', 'M', datetime.date(1988, 6, 25)),
#  (10912, datetime.date(1952, 7, 27), 'Oscal', 'Fasbender', 'M', datetime.date(1986, 4, 23)),
#  (10913, datetime.date(1952, 9, 3), 'Narain', 'Thummel', 'M', datetime.date(1992, 6, 25)),
#  (10914, datetime.date(1956, 4, 26), 'Mizuhito', 'Prochazka', 'M', datetime.date(1998, 3, 24)),
#  (10915, datetime.date(1961, 3, 11), 'Valery', 'Skafidas', 'M', datetime.date(1987, 12, 6)),
#  (10916, datetime.date(1962, 1, 3), 'Make', 'Spataro', 'M', datetime.date(1996, 7, 1)),
#  (10917, datetime.date(1956, 5, 10), 'Tesuya', 'Slaats', 'F', datetime.date(1987, 12, 3)),
#  (10918, datetime.date(1954, 12, 26), 'Susumu', 'Reghbati', 'M', datetime.date(1985, 12, 13)),
#  (10919, datetime.date(1961, 9, 4), 'Reinhard', 'Lindenbaum', 'M', datetime.date(1987, 4, 19)),
#  (10920, datetime.date(1955, 4, 8), 'Ronghao', 'Narahara', 'M', datetime.date(1991, 7, 9)),
#  (10921, datetime.date(1955, 7, 20), 'Mara', 'Bahi', 'F', datetime.date(1986, 7, 27)),
#  (10922, datetime.date(1953, 10, 27), 'Kyoichi', 'Wossner', 'M', datetime.date(1992, 8, 9)),
#  (10923, datetime.date(1957, 4, 29), 'Younwoo', 'Maquelin', 'M', datetime.date(1990, 4, 9)),
#  (10924, datetime.date(1954, 4, 27), 'Hironoby', 'Atchley', 'F', datetime.date(1988, 8, 14)),
#  (10925, datetime.date(1960, 2, 13), 'Heng', 'Waterhouse', 'F', datetime.date(1986, 9, 4)),
#  (10926, datetime.date(1954, 10, 13), 'Leni', 'Eppinger', 'F', datetime.date(1990, 4, 30)),
#  (10927, datetime.date(1953, 3, 13), 'Gal', 'Scallan', 'M', datetime.date(1985, 10, 26)),
#  (10928, datetime.date(1961, 11, 1), 'Udaiprakash', 'Schmezko', 'M', datetime.date(1991, 4, 7)),
#  (10929, datetime.date(1958, 10, 26), 'Sumali', 'Arlazarov', 'M', datetime.date(1991, 4, 15)),
#  (10930, datetime.date(1954, 1, 13), 'Arch', 'Minakawa', 'M', datetime.date(1990, 8, 9)),
#  (10931, datetime.date(1963, 6, 30), 'Abdulla', 'Beutelspacher', 'F', datetime.date(1992, 6, 14)),
#  (10932, datetime.date(1955, 11, 19), 'Avishai', 'Picci', 'F', datetime.date(1994, 9, 9)),
#  (10933, datetime.date(1965, 1, 24), 'Juyoung', 'Seghrouchni', 'F', datetime.date(1993, 8, 2)),
#  (10934, datetime.date(1960, 5, 21), 'Bartek', 'Strooper', 'F', datetime.date(1993, 11, 11)),
#  (10935, datetime.date(1961, 8, 9), 'Morris', 'Famili', 'M', datetime.date(1990, 3, 9)),
#  (10936, datetime.date(1953, 4, 8), 'Mountaz', 'Schicker', 'F', datetime.date(1987, 10, 27)),
#  (10937, datetime.date(1964, 9, 11), 'Anyuan', 'Nanard', 'M', datetime.date(1987, 8, 29)),
#  (10938, datetime.date(1958, 5, 11), 'Shaowei', 'Iisaku', 'F', datetime.date(1985, 9, 24)),
#  (10939, datetime.date(1964, 7, 13), 'Matk', 'Akazan', 'M', datetime.date(1990, 11, 1)),
#  (10940, datetime.date(1953, 1, 7), 'Aleksander', 'Fioravanti', 'F', datetime.date(1994, 12, 2)),
#  (10941, datetime.date(1960, 8, 26), 'Katsuyuki', 'Norsworthy', 'M', datetime.date(1993, 8, 22)),
#  (10942, datetime.date(1952, 8, 8), 'Toshimitsu', 'Larfeldt', 'F', datetime.date(1989, 9, 8)),
#  (10943, datetime.date(1955, 11, 19), 'Berna', 'Skafidas', 'M', datetime.date(1988, 2, 19)),
#  (10944, datetime.date(1952, 5, 25), 'Remko', 'Zyda', 'M', datetime.date(1991, 5, 24)),
#  (10945, datetime.date(1959, 9, 25), 'Kazuhiro', 'Kushnir', 'F', datetime.date(1990, 7, 4)),
#  (10946, datetime.date(1956, 9, 8), 'Shaz', 'Kabayashi', 'M', datetime.date(1996, 2, 4)),
#  (10947, datetime.date(1954, 9, 29), 'Gor', 'Usery', 'F', datetime.date(1995, 11, 16)),
#  (10948, datetime.date(1952, 12, 23), 'Shigehito', 'Brodie', 'M', datetime.date(1996, 9, 30)),
#  (10949, datetime.date(1953, 8, 14), 'Shigeichiro', 'Wroclawski', 'F', datetime.date(1990, 3, 13)),
#  (10950, datetime.date(1958, 12, 7), 'Sushant', 'Staylopatis', 'M', datetime.date(1996, 6, 8)),
#  (10951, datetime.date(1962, 1, 20), 'Marco', 'Iisaku', 'M', datetime.date(1989, 7, 6)),
#  (10952, datetime.date(1958, 8, 26), 'Inderjeet', 'Bharadwaj', 'M', datetime.date(1986, 7, 22)),
#  (10953, datetime.date(1956, 6, 23), 'Jahangir', 'Laventhal', 'F', datetime.date(1987, 2, 12)),
#  (10954, datetime.date(1964, 11, 16), 'Ranga', 'Burnard', 'F', datetime.date(1990, 8, 7)),
#  (10955, datetime.date(1959, 2, 24), 'Urs', 'Danley', 'F', datetime.date(1986, 9, 27)),
#  (10956, datetime.date(1955, 2, 2), 'Arno', 'Picel', 'M', datetime.date(1992, 6, 29)),
#  (10957, datetime.date(1961, 6, 6), 'Duke', 'Schnabel', 'M', datetime.date(1988, 1, 23)),
#  (10958, datetime.date(1958, 11, 7), 'Huican', 'Katalagarianos', 'M', datetime.date(1988, 11, 27)),
#  (10959, datetime.date(1956, 6, 19), 'Kerryn', 'Vigier', 'M', datetime.date(1994, 3, 1)),
#  (10960, datetime.date(1959, 10, 24), 'Billur', 'Braunschweig', 'M', datetime.date(1988, 3, 14)),
#  (10961, datetime.date(1957, 3, 28), 'Weiwu', 'Choobineh', 'M', datetime.date(1986, 5, 14)),
#  (10962, datetime.date(1956, 8, 23), 'Naraig', 'Kugler', 'F', datetime.date(1986, 12, 16)),
#  (10963, datetime.date(1957, 4, 15), 'Hatsukazu', 'Swist', 'M', datetime.date(1988, 1, 14)),
#  (10964, datetime.date(1962, 4, 2), 'Takushi', 'Bolsens', 'F', datetime.date(1990, 10, 11)),
#  (10965, datetime.date(1955, 7, 10), 'Eckart', 'Braunschweig', 'M', datetime.date(1986, 7, 29)),
#  (10966, datetime.date(1962, 7, 4), 'Danel', 'Pardalos', 'M', datetime.date(1989, 11, 7)),
#  (10967, datetime.date(1962, 10, 1), 'Eran', 'Adachi', 'M', datetime.date(1993, 8, 1)),
#  (10968, datetime.date(1961, 3, 19), 'Lakshmi', 'Kolinko', 'M', datetime.date(1985, 8, 11)),
#  (10969, datetime.date(1954, 9, 5), 'Premal', 'Noriega', 'M', datetime.date(1988, 8, 22)),
#  (10970, datetime.date(1962, 8, 24), 'Gen', 'Tiemann', 'F', datetime.date(1994, 9, 16)),
#  (10971, datetime.date(1955, 2, 8), 'Isamu', 'Vadhan', 'M', datetime.date(1991, 7, 30)),
#  (10972, datetime.date(1961, 10, 5), 'Fumiko', 'Asser', 'F', datetime.date(1987, 6, 6)),
#  (10973, datetime.date(1961, 10, 2), 'Valdiodio', 'Raczkowsky', 'M', datetime.date(1989, 3, 5)),
#  (10974, datetime.date(1952, 3, 7), 'Muneo', 'Papsdorf', 'M', datetime.date(1985, 11, 25)),
#  (10975, datetime.date(1962, 7, 27), 'Peternela', 'Birnbaum', 'F', datetime.date(1986, 10, 31)),
#  (10976, datetime.date(1963, 1, 27), 'Hitomi', 'Valette', 'F', datetime.date(1992, 12, 6)),
#  (10977, datetime.date(1957, 3, 19), 'Toong', 'Murrill', 'M', datetime.date(1987, 8, 10)),
#  (10978, datetime.date(1962, 9, 24), 'Huiqun', 'Bellone', 'M', datetime.date(1985, 5, 18)),
#  (10979, datetime.date(1959, 9, 11), 'Elrique', 'Raney', 'F', datetime.date(1986, 1, 27)),
#  (10980, datetime.date(1963, 11, 10), 'Filipp', 'Munawer', 'M', datetime.date(1989, 1, 4)),
#  (10981, datetime.date(1956, 7, 22), 'Sugwoo', 'Dulin', 'F', datetime.date(1989, 1, 3)),
#  (10982, datetime.date(1964, 2, 27), 'Yishay', 'Decleir', 'M', datetime.date(1989, 11, 11)),
#  (10983, datetime.date(1961, 8, 9), 'Somnath', 'Parascandalo', 'F', datetime.date(1988, 2, 22)),
#  (10984, datetime.date(1962, 11, 10), 'Pranjal', 'Billawala', 'F', datetime.date(1988, 7, 9)),
#  (10985, datetime.date(1952, 5, 31), 'Chiradeep', 'Furedi', 'F', datetime.date(1990, 12, 10)),
#  (10986, datetime.date(1954, 8, 11), 'Masako', 'Schiper', 'M', datetime.date(1985, 10, 11)),
#  (10987, datetime.date(1952, 11, 26), 'Flemming', 'Baezner', 'M', datetime.date(1995, 12, 19)),
#  (10988, datetime.date(1955, 6, 24), 'Chinya', 'Deyuan', 'M', datetime.date(1985, 6, 19)),
#  (10989, datetime.date(1954, 9, 8), 'Sumali', 'Candan', 'F', datetime.date(1985, 7, 20)),
#  (10990, datetime.date(1954, 10, 22), 'Shin', 'Foote', 'M', datetime.date(1988, 7, 6)),
#  (10991, datetime.date(1957, 5, 22), 'Munehiro', 'Aingworth', 'M', datetime.date(1993, 5, 21)),
#  (10992, datetime.date(1958, 11, 26), 'Zhensheng', 'Juneja', 'M', datetime.date(1988, 8, 1)),
#  (10993, datetime.date(1958, 11, 17), 'Arve', 'Erde', 'F', datetime.date(1992, 5, 29)),
#  (10994, datetime.date(1961, 6, 17), 'Divine', 'Aingworth', 'M', datetime.date(1987, 6, 29)),
#  (10995, datetime.date(1963, 2, 26), 'Chenye', 'Hertweck', 'F', datetime.date(1997, 7, 19)),
#  (10996, datetime.date(1955, 2, 1), 'Matk', 'Rahimi', 'F', datetime.date(1990, 2, 7)),
#  (10997, datetime.date(1959, 8, 30), 'Alselm', 'Parascandalo', 'F', datetime.date(1994, 5, 6)),
#  (10998, datetime.date(1956, 2, 17), 'Marlo', 'Kandlur', 'M', datetime.date(1992, 6, 28)),
#  (10999, datetime.date(1961, 12, 4), 'Insup', 'Benveniste', 'F', datetime.date(1996, 3, 5)),
#  (11000, datetime.date(1960, 9, 12), 'Alain', 'Bonifati', 'M', datetime.date(1988, 8, 20)),
#  ...]

# %% [markdown]
# ### Write a query to show the full names of employees

# %%
# %%sql
# SELECT CONCAT(first_name, ' ', last_name) AS emp_name
# FROM employees;
# Out:
#  * mysql+pymysql://miguel:***@localhost:3306/employees
# 300024 rows affected.
# [('Georgi Facello',),
#  ('Bezalel Simmel',),
#  ('Parto Bamford',),
#  ('Chirstian Koblick',),
#  ('Kyoichi Maliniak',),
#  ('Anneke Preusig',),
#  ('Tzvetan Zielinski',),
#  ('Saniya Kalloufi',),
#  ('Sumant Peac',),
#  ('Duangkaew Piveteau',),
#  ('Mary Sluis',),
#  ('Patricio Bridgland',),
#  ('Eberhardt Terkki',),
#  ('Berni Genin',),
#  ('Guoxiang Nooteboom',),
#  ('Kazuhito Cappelletti',),
#  ('Cristinel Bouloucos',),
#  ('Kazuhide Peha',),
#  ('Lillian Haddadi',),
#  ('Mayuko Warwick',),
#  ('Ramzi Erde',),
#  ('Shahaf Famili',),
#  ('Bojan Montemayor',),
#  ('Suzette Pettey',),
#  ('Prasadram Heyers',),
#  ('Yongqiao Berztiss',),
#  ('Divier Reistad',),
#  ('Domenick Tempesti',),
#  ('Otmar Herbst',),
#  ('Elvis Demeyer',),
#  ('Karsten Joslin',),
#  ('Jeong Reistad',),
#  ('Arif Merlo',),
#  ('Bader Swan',),
#  ('Alain Chappelet',),
#  ('Adamantios Portugali',),
#  ('Pradeep Makrucki',),
#  ('Huan Lortz',),
#  ('Alejandro Brender',),
#  ('Weiyi Meriste',),
#  ('Uri Lenart',),
#  ('Magy Stamatiou',),
#  ('Yishay Tzvieli',),
#  ('Mingsen Casley',),
#  ('Moss Shanbhogue',),
#  ('Lucien Rosenbaum',),
#  ('Zvonko Nyanchama',),
#  ('Florian Syrotiuk',),
#  ('Basil Tramer',),
#  ('Yinghua Dredge',),
#  ('Hidefumi Caine',),
#  ('Heping Nitsch',),
#  ('Sanjiv Zschoche',),
#  ('Mayumi Schueller',),
#  ('Georgy Dredge',),
#  ('Brendon Bernini',),
#  ('Ebbe Callaway',),
#  ('Berhard McFarlin',),
#  ('Alejandro McAlpine',),
#  ('Breannda Billingsley',),
#  ('Tse Herber',),
#  ('Anoosh Peyn',),
#  ('Gino Leonhardt',),
#  ('Udi Jansch',),
#  ('Satosi Awdeh',),
#  ('Kwee Schusler',),
#  ('Claudi Stavenow',),
#  ('Charlene Brattka',),
#  ('Margareta Bierman',),
#  ('Reuven Garigliano',),
#  ('Hisao Lipner',),
#  ('Hironoby Sidou',),
#  ('Shir McClurg',),
#  ('Mokhtar Bernatsky',),
#  ('Gao Dolinsky',),
#  ('Erez Ritzmann',),
#  ('Mona Azuma',),
#  ('Danel Mondadori',),
#  ('Kshitij Gils',),
#  ('Premal Baek',),
#  ('Zhongwei Rosen',),
#  ('Parviz Lortz',),
#  ('Vishv Zockler',),
#  ('Tuval Kalloufi',),
#  ('Kenroku Malabarba',),
#  ('Somnath Foote',),
#  ('Xinglin Eugenio',),
#  ('Jungsoon Syrzycki',),
#  ('Sudharsan Flasterstein',),
#  ('Kendra Hofting',),
#  ('Amabile Gomatam',),
#  ('Valdiodio Niizuma',),
#  ('Sailaja Desikan',),
#  ('Arumugam Ossenbruggen',),
#  ('Hilari Morton',),
#  ('Jayson Mandell',),
#  ('Remzi Waschkowski',),
#  ('Sreekrishna Servieres',),
#  ('Valter Sullins',),
#  ('Hironobu Haraldson',),
#  ('Perla Heyers',),
#  ('Paraskevi Luby',),
#  ('Akemi Birch',),
#  ('Xinyu Warwick',),
#  ('Hironoby Piveteau',),
#  ('Eben Aingworth',),
#  ('Dung Baca',),
#  ('Lunjin Giveon',),
#  ('Mariusz Prampolini',),
#  ('Xuejia Ullian',),
#  ('Hugo Rosis',),
#  ('Yuichiro Swick',),
#  ('Jaewon Syrzycki',),
#  ('Munir Demeyer',),
#  ('Chikara Rissland',),
#  ('Dayanand Czap',),
#  ('Kiyotoshi Blokdijk',),
#  ('Zhonghui Zyda',),
#  ('Domenick Peltason',),
#  ('Armond Fairtlough',),
#  ('Guoxiang Ramsay',),
#  ('Ohad Esposito',),
#  ('Hinrich Randi',),
#  ('Geraldo Marwedel',),
#  ('Syozo Hiltgen',),
#  ('Kayoko Valtorta',),
#  ('Subir Baja',),
#  ('Babette Lamba',),
#  ('Armond Peir',),
#  ('Nishit Casperson',),
#  ('Magdalena Eldridge',),
#  ('Ayakannu Skrikant',),
#  ('Giri Isaak',),
#  ('Diederik Siprelle',),
#  ('Nathan Monkewich',),
#  ('Zissis Pintelas',),
#  ('Maren Hutton',),
#  ('Perry Shimshoni',),
#  ('Ewing Foong',),
#  ('Yucel Auria',),
#  ('Shahaf Ishibashi',),
#  ('Tzvetan Hettesheimer',),
#  ('Sakthirel Bakhtari',),
#  ('Marla Brendel',),
#  ('Akemi Esposito',),
#  ('Chenyi Syang',),
#  ('Kazuhito Encarnacion',),
#  ('Douadi Azumi',),
#  ('Xiadong Perry',),
#  ('Zhenbing Perng',),
#  ('Itzchak Lichtner',),
#  ('Jaques Munro',),
#  ('Heekeun Majewski',),
#  ('Abdulah Thibadeau',),
#  ('Adas Nastansky',),
#  ('Sumali Fargier',),
#  ('Nigel Aloisi',),
#  ('Khedija Mitsuhashi',),
#  ('Serif Buescher',),
#  ('Debatosh Khasidashvili',),
#  ('Hairong Mellouli',),
#  ('Florina Eugenio',),
#  ('Karsten Szmurlo',),
#  ('Jagoda Braunmuhl',),
#  ('Miyeon Macedo',),
#  ('Samphel Siegrist',),
#  ('Duangkaew Rassart',),
#  ('Dharmaraja Stassinopoulos',),
#  ('Sampalli Snedden',),
#  ('Kasturi Jenevein',),
#  ('Herbert Trachtenberg',),
#  ('Shigeu Matzen',),
#  ('Shrikanth Mahmud',),
#  ('Badri Furudate',),
#  ('Aleksandar Ananiadou',),
#  ('Brendon Lenart',),
#  ('Pragnesh Iisaka',),
#  ('Valery Litvinov',),
#  ('Deniz Duclos',),
#  ('Shaw Wendorf',),
#  ('Sibyl Nooteboom',),
#  ('Moriyoshi Merey',),
#  ('Mechthild Bonifati',),
#  ('Mihalis Lowrie',),
#  ('Duro Sidhu',),
#  ('Shigehito Kropatsch',),
#  ('Tommaso Narwekar',),
#  ('Christ Muchinsky',),
#  ('Khalid Erva',),
#  ('Arve Fairtlough',),
#  ('Zdislav Nastansky',),
#  ('Mohua Falck',),
#  ('Masaru Cheshire',),
#  ('Josyula Hofmeyr',),
#  ('Annemarie Redmiles',),
#  ('Marc Hellwagner',),
#  ('Kasidit Krzyzanowski',),
#  ('Pranav Furedi',),
#  ('Kazuhisa Ranta',),
#  ('Vidya Awdeh',),
#  ('Idoia Kavraki',),
#  ('Greger Lichtner',),
#  ('Steen Escriba',),
#  ('Nevio Ritcey',),
#  ('Mabhin Leijenhorst',),
#  ('Alassane Iwayama',),
#  ('Girolamo Anandan',),
#  ('Xiping Klerer',),
#  ('Yolla Ellozy',),
#  ('Yuping Alpin',),
#  ('Vishu Strehl',),
#  ('Divier Esteva',),
#  ('Jackson Kakkad',),
#  ('Tadahiko Ciolek',),
#  ('Xiaobin Duclos',),
#  ('Amstein Ghemri',),
#  ('Yongmin Roison',),
#  ('Zhenhua Magalhaes',),
#  ('Genta Kolvik',),
#  ('Kish Fasbender',),
#  ('Yucai Granlund',),
#  ('Tze Nourani',),
#  ('Carrsten Schmiedel',),
#  ('Leon Trogemann',),
#  ('Kellie Chinen',),
#  ('Xinglin Plessier',),
#  ('Anneli Kaiser',),
#  ('Karoline Cesareni',),
#  ('Ulises Takanami',),
#  ('Clyde Vernadat',),
#  ('Shaowen Desikan',),
#  ('Marko Auria',),
#  ('Lein Vendrig',),
#  ('Arunachalam Bakhtari',),
#  ('Susanta Roccetti',),
#  ('Susumu Bade',),
#  ('Yannis Mandell',),
#  ('Mototsugu Gire',),
#  ('Nikolaos Llado',),
#  ('Remko Maccarone',),
#  ('Ortrud Murillo',),
#  ('Lunjin Ozeri',),
#  ('Wonhee Pouyioutas',),
#  ('Foong Flasterstein',),
#  ('Ramalingam Gente',),
#  ('Basem Teitelbaum',),
#  ('Heon Riefers',),
#  ('Frederique Tempesti',),
#  ('Marie Boreale',),
#  ('Serap Etalle',),
#  ('Alair Rosenbaum',),
#  ('Shirish Wegerle',),
#  ('Zsolt Salinas',),
#  ('Shen Brattka',),
#  ('Roddy Garnick',),
#  ('Irene Radhakrishnan',),
#  ('Aiman Riexinger',),
#  ('Basil Ishibashi',),
#  ('Susanna Vesel',),
#  ('Alper Suomi',),
#  ('Mang Erie',),
#  ('Mahendra Maraist',),
#  ('Takahiro Waterhouse',),
#  ('Nalini Kawashimo',),
#  ('Ramalingam Muniz',),
#  ('Sukumar Rassart',),
#  ('Shaunak Cullers',),
#  ('Nishit Siochi',),
#  ('Taizo Oxman',),
#  ('Bedir Hartvigsen',),
#  ('Sham Eastman',),
#  ('Yishai Cannane',),
#  ('Baocai Lieblein',),
#  ('Dmitri Pearson',),
#  ('Marek Luck',),
#  ('Xuejun Hempstead',),
#  ('Isaac Schwartzbauer',),
#  ('Lubomir Nitsch',),
#  ('Barton Jumpertz',),
#  ('Stabislas Delgrange',),
#  ('Moty Kusakari',),
#  ('Hercules Benzmuller',),
#  ('Kauko Birjandi',),
#  ('Masali Murrill',),
#  ('Zhonghui Preusig',),
#  ('Saddek Gopalakrishnan',),
#  ('Marie Pietracaprina',),
#  ('Selwyn Perri',),
#  ('Shay Poulakidas',),
#  ('Yongmao Pleszkun',),
#  ('Dipayan Seghrouchni',),
#  ('Yucel Ghelli',),
#  ('Mihalis Avouris',),
#  ('Rutger Miara',),
#  ('Kristine Velardi',),
#  ('Petter Lorho',),
#  ('Narain Oaver',),
#  ('Dietrich DuCasse',),
#  ('Ipke Stentiford',),
#  ('Tadahiko Ulupinar',),
#  ('Lucien Staudhammer',),
#  ('Faiza Baer',),
#  ('Marlo Zschoche',),
#  ('Bernt Erie',),
#  ('Hirochika Piancastelli',),
#  ('Heng Kilgour',),
#  ('Nikolaos Leaver',),
#  ('Dzung Holburn',),
#  ('Prodip Schusler',),
#  ('Aksel Alencar',),
#  ('Hsiangchu Molenkamp',),
#  ('Rasiah Deyuan',),
#  ('Subbu Riexinger',),
#  ('Christfried Apsitis',),
#  ('Maris Angelopoulos',),
#  ('Christoper Schwaller',),
#  ('Arie Birge',),
#  ('Mototsugu Beilner',),
#  ('Mechthild Miyakawa',),
#  ('Uinam Stasinski',),
#  ('Guenter Ravishankar',),
#  ('Isamu Dahlbom',),
#  ('Kankanahalli Hinsberger',),
#  ('Bernardo Rouquie',),
#  ('Arunachalam Badr',),
#  ('Masali Czap',),
#  ('Roded Facello',),
#  ('Serenella Kawashima',),
#  ('Remko Shigei',),
#  ('Kasturi Bellmore',),
#  ('Arto Binkley',),
#  ('Masanao Bain',),
#  ('Snehasis Dymetman',),
#  ('Falguni Erie',),
#  ('Toshimori Bahi',),
#  ('Goa Rothe',),
#  ('Jeong Sadowsky',),
#  ('Heon Ranai',),
#  ('Teunis Liedekerke',),
#  ('Djelloul Laventhal',),
#  ('Wilmer Greenaway',),
#  ('Stella Hiroyama',),
#  ('Dinah Syrzycki',),
#  ('Uwe Garnier',),
#  ('Arra Ratnakar',),
#  ('Aamod Radwan',),
#  ('Pradeep Kaminger',),
#  ('Mahendra Picco',),
#  ('Oksana Brodie',),
#  ('Kristen Kavvadias',),
#  ('Tadahiko Strehl',),
#  ('Erzsebet Ohori',),
#  ('Phule Hammerschmidt',),
#  ('Moto Kusakari',),
#  ('Satyanarayana Cochrane',),
#  ('Vasilis Standera',),
#  ('Hausi Sidhu',),
#  ('Qunsheng Tagansky',),
#  ('Heekeun Sambasivam',),
#  ('Irene Munck',),
#  ('Seshu Sidou',),
#  ('Shalesh dAstous',),
#  ('Toshiki Muniz',),
#  ('Nakhoon Dengi',),
#  ('Rosine Granlund',),
#  ('Morrie Piazza',),
#  ('Hyuckchul Gini',),
#  ('Hatim Koshiba',),
#  ('Qunsheng Toyoshima',),
#  ('Clyde Fandrianto',),
#  ('Ioana Kirkerud',),
#  ('Anneli Frijda',),
#  ('Hongzue Heijenga',),
#  ('Willard Rosin',),
#  ('Dante Kalafatis',),
#  ('Fai Bale',),
#  ('Marl Grospietsch',),
#  ('Takahira Lichtner',),
#  ('Mikhail Rosis',),
#  ('Alejandro Kamble',),
#  ('Jiong Parfitt',),
#  ('Shirish Dredge',),
#  ('Leucio Aumann',),
#  ('Feiyu Luft',),
#  ('Khatoun Imataki',),
#  ('Eishiro Miyakawa',),
#  ('Parto Wrigley',),
#  ('Hironoby Kaiser',),
#  ('Make Peir',),
#  ('Wanqing Bratten',),
#  ('Hongzue Akaboshi',),
#  ('Jiann Hainaut',),
#  ('Yagil DasSarma',),
#  ('Shawna Meriste',),
#  ('Takahiro Deverell',),
#  ('Sibyl Rahier',),
#  ('Irena Reutenauer',),
#  ('Shooichi Escriba',),
#  ('Guenter Marchegay',),
#  ('Ortrud Nitto',),
#  ('Eckart Barriga',),
#  ('Volkmar Ebeling',),
#  ('Atreyi Mungall',),
#  ('Prodip Rosti',),
#  ('Hilary Budinsky',),
#  ('Sigeru Wynblatt',),
#  ('Ulf Siepmann',),
#  ('Martijn Kaiser',),
#  ('Mario Straney',),
#  ('Takahito Gecsei',),
#  ('Lidong Klerer',),
#  ('Masoud Fabrizio',),
#  ('Danel Impagliazzo',),
#  ('Yinlin Alpin',),
#  ('Mark Coorg',),
#  ('Uli Keustermans',),
#  ('Bingning Bakhtari',),
#  ('Candida Porotnikoff',),
#  ('Maria Bauknecht',),
#  ('Kaijung Riesenhuber',),
#  ('Divine Marzano',),
#  ('Greger Rubsam',),
#  ('Dante Cronin',),
#  ('Babette Straney',),
#  ('Sashi Osgood',),
#  ('Arunas Luce',),
#  ('Khosrow Sudbeck',),
#  ('Cathie Brlek',),
#  ('Martien Improta',),
#  ('Ferdinand Chenney',),
#  ('Patricio Bugrara',),
#  ('Hisao Tiemann',),
#  ('Reuven Dengi',),
#  ('Dzung Peltason',),
#  ('Marsha Tagansky',),
#  ('Yahiko Lammel',),
#  ('Narain Reeker',),
#  ('Evgueni Srimani',),
#  ('Jolita Jarecki',),
#  ('Akeel Narahara',),
#  ('Adel Perfilyeva',),
#  ('Volkmar Unno',),
#  ('Shichao Litvinov',),
#  ('Kazuhira Rosis',),
#  ('Junichi Kavanagh',),
#  ('Ebru Chepyzhov',),
#  ('Ronghao Yavatkar',),
#  ('Phule Oxenboll',),
#  ('Aleksandar Sudkamp',),
#  ('Khun Harbusch',),
#  ('Bodh Ranta',),
#  ('Werner Hasham',),
#  ('Tsvetan Matzel',),
#  ('Wonhee Badr',),
#  ('Sverrir Streng',),
#  ('Stepehn Hardjono',),
#  ('Oddvar Schlenzig',),
#  ('Gina Engelmann',),
#  ('Ennio Trogemann',),
#  ('Shushma VanScheik',),
#  ('Gal Karcich',),
#  ('Sumali Schlenzig',),
#  ('Ung Zaiane',),
#  ('Mang Maginnis',),
#  ('Claudi Shackel',),
#  ('Jiakeng Himler',),
#  ('Dipayan Suomi',),
#  ('Yoshimitsu Shobatake',),
#  ('Munehiko Ananiadou',),
#  ('Peternela Iwayama',),
#  ('Jouko Yamaashi',),
#  ('Salvador Lodder',),
#  ('Przemyslawa Oskamp',),
#  ('Kenton Garnham',),
#  ('Mario Rodite',),
#  ('Kokou Iisaka',),
#  ('Guoxiang Trogemann',),
#  ('Maik Ushiama',),
#  ('Duro Coney',),
#  ('Make Baba',),
#  ('Yongmao Pintelas',),
#  ('Goa Pleszkun',),
#  ('Zhiwei Anick',),
#  ('Nirmal Varley',),
#  ('Teruyuki Sundgren',),
#  ('Amstein Kossowski',),
#  ('Perla Middleton',),
#  ('Mihalis Heering',),
#  ('Elvia Homond',),
#  ('Huiqun Vuskovic',),
#  ('Garnik Narahari',),
#  ('Lobel Kumaresan',),
#  ('Maris Haraldson',),
#  ('Yakkov Servieres',),
#  ('Anyuan Zhiwei',),
#  ('Gretta Baig',),
#  ('Pramod Rabehasaina',),
#  ('Valter Cappelletti',),
#  ('Maik Luft',),
#  ('Vojin Narwekar',),
#  ('Susuma Larfeldt',),
#  ('Yonghoan Marshall',),
#  ('Dannz Pell',),
#  ('Xiong Varker',),
#  ('Isamu Auria',),
#  ('Kazuhisa Kroll',),
#  ('Kasidit Belinskaya',),
#  ('Kotesh Liedekerke',),
#  ('Abdelwaheb Riesenhuber',),
#  ('Keung Slobodova',),
#  ('Khoa Marrevee',),
#  ('Udi Gihr',),
#  ('Yuichiro Schicker',),
#  ('Tomofumi McClure',),
#  ('Raimond Kirkerud',),
#  ('Xiadong Luga',),
#  ('Tiina Speek',),
#  ('Marin Lanphier',),
#  ('Yonghoan Alencar',),
#  ('Jenwei Ecklund',),
#  ('Kwangsub Setia',),
#  ('Marke Cesareni',),
#  ('Malu Skafidas',),
#  ('Shigehiro Cincotta',),
#  ('Yuchang Lunt',),
#  ('Kwangho Theuretzbacher',),
#  ('Tetsushi Barvinok',),
#  ('Koichi Lakshmanan',),
#  ('Ymte Yetto',),
#  ('Boriana Coors',),
#  ('Oguz Gimbel',),
#  ('Mary Wossner',),
#  ('Mohamadou Smailagic',),
#  ('Dinah Bahl',),
#  ('Shalesh Stroustrup',),
#  ('Yechiam Sambasivam',),
#  ('Stella Benzmuller',),
#  ('Przemyslawa Falby',),
#  ('Yucel Reinhard',),
#  ('Martins Barriga',),
#  ('Godehard Eiter',),
#  ('Yannis Couchot',),
#  ('Lein Lichtman',),
#  ('Ishfaq Krzyzanowski',),
#  ('Hauke dAstous',),
#  ('Nechama Schapiro',),
#  ('Snehasis Brobst',),
#  ('Ramalingam Gunderson',),
#  ('Beshir Kisuki',),
#  ('Manton Leuchs',),
#  ('Jeong Rijsenbrij',),
#  ('Kazuhito Shiratori',),
#  ('Rajmohan Wallrath',),
#  ('Dines Gerlach',),
#  ('Vitaly Picci',),
#  ('JoAnna Taubman',),
#  ('Sashi Karlin',),
#  ('Hisao Famili',),
#  ('Arumugam Comellas',),
#  ('Yinlin Esteva',),
#  ('Serge Joslin',),
#  ('Shuky Pearson',),
#  ('Mohit Spelt',),
#  ('Jianhao Thisen',),
#  ('Yishay Harnett',),
#  ('Jianhui Zuberek',),
#  ('Dietrich Journel',),
#  ('Gao Poulakidas',),
#  ('Sreenivas Bashian',),
#  ('Alassane Morrin',),
#  ('Fun Varman',),
#  ('Cordelia Axelband',),
#  ('Tetsushi Speel',),
#  ('Salvador Olano',),
#  ('Theirry Yeung',),
#  ('Xiaoqiu Krychniak',),
#  ('Ennio Schmiedel',),
#  ('Shigeaki Shanbhogue',),
#  ('Aiman Stentiford',),
#  ('Christoper Rehfuss',),
#  ('Odinaldo Prochazka',),
#  ('Shmuel Juneja',),
#  ('Prasadram Stille',),
#  ('Mana Papastamatiou',),
#  ('Sajjad Willoner',),
#  ('Kirk Vuskovic',),
#  ('Behnaam Srimani',),
#  ('Shigeo Dulay',),
#  ('Subbu Sanella',),
#  ('Yongqiao Kalloufi',),
#  ('Hidde Hettesheimer',),
#  ('Almudena Alvarado',),
#  ('Falguni Kenevan',),
#  ('Kiyokazu Whitcomb',),
#  ('Giri Undy',),
#  ('Sanjit Coors',),
#  ('Lucien Schaad',),
#  ('Margo Gronowski',),
#  ('Seshu Crelier',),
#  ('Emran Rettelbach',),
#  ('Barton Usdin',),
#  ('Douadi Wossner',),
#  ('Wayne Restivo',),
#  ('Susanna Brizzi',),
#  ('Moti Wixon',),
#  ('Toshiki Marakhovsky',),
#  ('Rosalyn Hambrick',),
#  ('Adhemar Talmor',),
#  ('Janche Zhang',),
#  ('Irena Roccetti',),
#  ('Karsten Blokdijk',),
#  ('Gil Peroz',),
#  ('Inderjeet Jansen',),
#  ('Gila Ozeri',),
#  ('Keung Delgrande',),
#  ('Tommaso Marwedel',),
#  ('Hidekazu Angel',),
#  ('Ranga Yeung',),
#  ('Vivian Kusakabe',),
#  ('Marit Veeraraghavan',),
#  ('Hinrich Siepmann',),
#  ('Turgut Narlikar',),
#  ('Aleksander Danlos',),
#  ('Sham Gyorkos',),
#  ('Leszek Petereit',),
#  ('Danil Deverell',),
#  ('Shigeu Itzfeldt',),
#  ('Krisda Krogh',),
#  ('Lalit Francisci',),
#  ('Bezalel Katzenelson',),
#  ('Inderjeet Chaudhuri',),
#  ('Yoshimitsu Velardi',),
#  ('Sorina Herber',),
#  ('Nahid Chepyzhov',),
#  ('Toney Angiulli',),
#  ('Saeko Porotnikoff',),
#  ('Heejo Frolund',),
#  ('Jenwei Borovoy',),
#  ('Pramod Erol',),
#  ('Anneke Meszaros',),
#  ('Guozhong Zucker',),
#  ('Hirochika Narlikar',),
#  ('Slavian Keirsey',),
#  ('Pranas Benaini',),
#  ('Fumiyo Esposito',),
#  ('Uri Chorvat',),
#  ('Tesuro Bahk',),
#  ('Marlo Ratnaker',),
#  ('Vitali Welham',),
#  ('Hongzhu Chepyzhov',),
#  ('Zijian Maginnis',),
#  ('Danai Chachaty',),
#  ('Otmar Feinberg',),
#  ('Nahla Castellani',),
#  ('Remko Dalton',),
#  ('Sanjay Litzkow',),
#  ('Juichirou Kitsuregawa',),
#  ('Junsik Rijckaert',),
#  ('Dinah Shackel',),
#  ('Jouko Kolinko',),
#  ('Ottavia Giarratana',),
#  ('Arto Serra',),
#  ('Teunis Noriega',),
#  ('Xumin Peck',),
#  ('Qingxiang Snyers',),
#  ('Zhonghua Reeker',),
#  ('Makato Cusworth',),
#  ('Maren Granlund',),
#  ('Yurij Iisaka',),
#  ('Shunichi McAffer',),
#  ('Parviz Rebaine',),
#  ('Bluma Zeilberger',),
#  ('Hyuckchul Casperson',),
#  ('Abdelaziz Bisiani',),
#  ('Ymte Waschkowski',),
#  ('Valeri Danley',),
#  ('Alejandra Perng',),
#  ('Chriss Gide',),
#  ('Neven Brender',),
#  ('Kish Honglei',),
#  ('Florina Garnier',),
#  ('Bedir Haumacher',),
#  ('Guiseppe Stranks',),
#  ('Aimee Tokunaga',),
#  ('Zongyan Cusworth',),
#  ('Avishai Azadmanesh',),
#  ('Leon Kaiser',),
#  ('Xiaopeng Lanphier',),
#  ('Satoru Otillio',),
#  ('Matt Jumpertz',),
#  ('Denny Setia',),
#  ('Larisa Bage',),
#  ('Berhard Daescu',),
#  ('Rildo Straney',),
#  ('Zorica Acton',),
#  ('Unal Fendler',),
#  ('Bluma Hiltgen',),
#  ('Barton Engberts',),
#  ('Hatim Deverell',),
#  ('Angel Mondadori',),
#  ('Hyuncheol Zolotykh',),
#  ('Bader Szemeredi',),
#  ('Giri Baumann',),
#  ('Yolla Kropatsch',),
#  ('Hironobu Wynblatt',),
#  ('Gonzalo Eldridge',),
#  ('Moty Trystram',),
#  ('Aral Erman',),
#  ('Jiafu Mateescu',),
#  ('Sorina Kermarrec',),
#  ('Arvind DuBourdieux',),
#  ('Uma Koprowski',),
#  ('Jagoda Naumovich',),
#  ('Aran Sadowsky',),
#  ('Goa Poehlman',),
#  ('Aiman Constantine',),
#  ('Serap Tasistro',),
#  ('Adib Rullman',),
#  ('Guenter Karunanithi',),
#  ('Odinaldo Kruskal',),
#  ('Bernd Redmiles',),
#  ('Dung Gornas',),
#  ('Eckart Harnett',),
#  ('Aluzio Narlikar',),
#  ('Garnet Isard',),
#  ('Zita Minakawa',),
#  ('Saeed Kitai',),
#  ('Ugo Maliniak',),
#  ('Percy Lorho',),
#  ('Mohit Janetzko',),
#  ('Fumitaka Peak',),
#  ('Morris Andreotta',),
#  ('Sangeeta Rodham',),
#  ('Sachar Erdi',),
#  ('Morrie Gewali',),
#  ('Gurbir Hellwagner',),
#  ('Vincent Schwartzbauer',),
#  ('Rosita Oppitz',),
#  ('Gor Iacovou',),
#  ('Suzette Sadowski',),
#  ('Sven Huttel',),
#  ('Shim Wiegley',),
#  ('Kiyomitsu Peltason',),
#  ('Yaghout Syang',),
#  ('Poorav Ranze',),
#  ('Kolar Usery',),
#  ('Falguni Khalid',),
#  ('Yuchang Francisci',),
#  ('King Brendel',),
#  ('Roddy Demeyer',),
#  ('Jordanka Ushiama',),
#  ('Byong Conde',),
#  ('Pradeep Harbusch',),
#  ('Chenyi Feinberg',),
#  ('Odysseas Ressouche',),
#  ('Paddy Brizzi',),
#  ('Florina Simkin',),
#  ('Fumiyo Boyle',),
#  ('JiYoung Chenney',),
#  ('Phillip Dratva',),
#  ('Sumali Liedekerke',),
#  ('Lech Himler',),
#  ('Giap Bolsens',),
#  ('Yunming Beetstra',),
#  ('Goetz Norsworthy',),
#  ('Nathalie Standera',),
#  ('Monique Doering',),
#  ('Ishfaq Candan',),
#  ('Vishv Bouloucos',),
#  ('Bedir Perry',),
#  ('Guiseppe Kleiser',),
#  ('Munehiro Dayana',),
#  ('Avishai Bahr',),
#  ('Jacqueline Masand',),
#  ('Xiaoheng Sluis',),
#  ('Mahmut Skafidas',),
#  ('Mizuhito Kemmerer',),
#  ('Selwyn Merey',),
#  ('Mori Yavatkar',),
#  ('Goncalo Staudhammer',),
#  ('Patricio Leuchs',),
#  ('Kish Perna',),
#  ('Moty Kenevan',),
#  ('Weijing Bottner',),
#  ('Keiichiro Marzano',),
#  ('Patricia dAstous',),
#  ('Shiv Neimat',),
#  ('Frazer Ullian',),
#  ('Aruna Journel',),
#  ('Yurij Schonegge',),
#  ('Tadahiko Sgarro',),
#  ('Chinya Birdsall',),
#  ('Oksana Roisin',),
#  ('Teunis Berztiss',),
#  ('Supot Naudin',),
#  ('Khoa Rousseau',),
#  ('Goetz Hiyoshi',),
#  ('Elliott Bednarek',),
#  ('Gad Griswold',),
#  ('Yuchang Matzke',),
#  ('Uinam Zschoche',),
#  ('Masato Setlzner',),
#  ('Katsuyuki Velasco',),
#  ('Terresa Benantar',),
#  ('Kerhong Bernick',),
#  ('Giap Matzel',),
#  ('Munehiro Zallocco',),
#  ('Chenxi Leijenhorst',),
#  ('Shim Feldhoffer',),
#  ('Lijie Lunn',),
#  ('Ashish Fortenbacher',),
#  ('Berthier Menhoudj',),
#  ('Shalesh Shumilov',),
#  ('Nidapan Dymetman',),
#  ('Renny Pramanik',),
#  ('Morris Caine',),
#  ('Uri Rullman',),
#  ('Huan Monarch',),
#  ('Pascal Sooriamurthi',),
#  ('Baocai Pena',),
#  ('Irena Schurmann',),
#  ('Masaru Passino',),
#  ('Arfst Mikschl',),
#  ('Kirk Kalsbeek',),
#  ('Fan Fairtlough',),
#  ('Arnd Anandan',),
#  ('Willard Danley',),
#  ('Godehard Gammage',),
#  ('Alper Narahara',),
#  ('Fen Fiebach',),
#  ('Toong Driscoll',),
#  ('Hidde Bergere',),
#  ('Krisda Gecseg',),
#  ('Huiqun Rajcani',),
#  ('Tomoyuki Kermarrec',),
#  ('Jianhua Leivant',),
#  ('Chuanti Karlin',),
#  ('Deniz Ramras',),
#  ('Gurbir Katiyar',),
#  ('Mohammad Koshino',),
#  ('Pranav Lieberherr',),
#  ('Berni Sanella',),
#  ('Honesty Smeets',),
#  ('Dipayan Koprowski',),
#  ('Hidde Tasistro',),
#  ('Tokuyasu Serre',),
#  ('Theirry Danley',),
#  ('Fen Bratsberg',),
#  ('Makato Mayerwieser',),
#  ('Florina Schapire',),
#  ('Piyawadee Copas',),
#  ('Hercules Munck',),
#  ('Yoshinari Kalloufi',),
#  ('Jagoda Nannarelli',),
#  ('Kwangho Reinhart',),
#  ('Sreenivas Peck',),
#  ('Fusako Stenning',),
#  ('Kenroku Gonthier',),
#  ('King Bernini',),
#  ('Gino Werthner',),
#  ('Howell Baek',),
#  ('Zhenbing Kadhim',),
#  ('Byong Bhattacharjee',),
#  ('Elliott Spieker',),
#  ('Danco Etalle',),
#  ('Fayez Yeung',),
#  ('Billur Gyorkos',),
#  ('Houman Unno',),
#  ('Guangming Jonsson',),
#  ('Shahid Leppanen',),
#  ('Aram Gilg',),
#  ('Karoline Speel',),
#  ('Sukumar Wegerle',),
#  ('Mahmut Borstler',),
#  ('Filipp Suri',),
#  ('Vincent Papastamatiou',),
#  ('Subir Biron',),
#  ('Lakshmi Deville',),
#  ('Muzhong Chleq',),
#  ('Weiye Nitsche',),
#  ('Katsuo Miake',),
#  ('Fun Heuser',),
#  ('Shimshon Champarnaud',),
#  ('Teunis Kleiser',),
#  ('Rayond Cronau',),
#  ('Sushant Begiun',),
#  ('Lunjin DeMori',),
#  ('Kwangho Dredge',),
#  ('Cheong Coors',),
#  ('Ramzi Furudate',),
#  ('Susanne Jiang',),
#  ('Kazunori Vieth',),
#  ('Danil Kropatsch',),
#  ('Suebskul Srimani',),
#  ('Vishwani Petersohn',),
#  ('Adil Taubenfeld',),
#  ('Arno Kumaresan',),
#  ('Munenori Markovitch',),
#  ('Valery Rousseau',),
#  ('Ferdinand Prenel',),
#  ('Chrisa Narahara',),
#  ('Inderjeet Perly',),
#  ('Visit Nyanchama',),
#  ('Debatosh Colorni',),
#  ('Jianhui Aloia',),
#  ('Munehiro Carrere',),
#  ('JiYoung Luks',),
#  ('Rajmohan Koblick',),
#  ('Georgi Atchley',),
#  ('Arco Jervis',),
#  ('Shay Casley',),
#  ('Oscal Fasbender',),
#  ('Narain Thummel',),
#  ('Mizuhito Prochazka',),
#  ('Valery Skafidas',),
#  ('Make Spataro',),
#  ('Tesuya Slaats',),
#  ('Susumu Reghbati',),
#  ('Reinhard Lindenbaum',),
#  ('Ronghao Narahara',),
#  ('Mara Bahi',),
#  ('Kyoichi Wossner',),
#  ('Younwoo Maquelin',),
#  ('Hironoby Atchley',),
#  ('Heng Waterhouse',),
#  ('Leni Eppinger',),
#  ('Gal Scallan',),
#  ('Udaiprakash Schmezko',),
#  ('Sumali Arlazarov',),
#  ('Arch Minakawa',),
#  ('Abdulla Beutelspacher',),
#  ('Avishai Picci',),
#  ('Juyoung Seghrouchni',),
#  ('Bartek Strooper',),
#  ('Morris Famili',),
#  ('Mountaz Schicker',),
#  ('Anyuan Nanard',),
#  ('Shaowei Iisaku',),
#  ('Matk Akazan',),
#  ('Aleksander Fioravanti',),
#  ('Katsuyuki Norsworthy',),
#  ('Toshimitsu Larfeldt',),
#  ('Berna Skafidas',),
#  ('Remko Zyda',),
#  ('Kazuhiro Kushnir',),
#  ('Shaz Kabayashi',),
#  ('Gor Usery',),
#  ('Shigehito Brodie',),
#  ('Shigeichiro Wroclawski',),
#  ('Sushant Staylopatis',),
#  ('Marco Iisaku',),
#  ('Inderjeet Bharadwaj',),
#  ('Jahangir Laventhal',),
#  ('Ranga Burnard',),
#  ('Urs Danley',),
#  ('Arno Picel',),
#  ('Duke Schnabel',),
#  ('Huican Katalagarianos',),
#  ('Kerryn Vigier',),
#  ('Billur Braunschweig',),
#  ('Weiwu Choobineh',),
#  ('Naraig Kugler',),
#  ('Hatsukazu Swist',),
#  ('Takushi Bolsens',),
#  ('Eckart Braunschweig',),
#  ('Danel Pardalos',),
#  ('Eran Adachi',),
#  ('Lakshmi Kolinko',),
#  ('Premal Noriega',),
#  ('Gen Tiemann',),
#  ('Isamu Vadhan',),
#  ('Fumiko Asser',),
#  ('Valdiodio Raczkowsky',),
#  ('Muneo Papsdorf',),
#  ('Peternela Birnbaum',),
#  ('Hitomi Valette',),
#  ('Toong Murrill',),
#  ('Huiqun Bellone',),
#  ('Elrique Raney',),
#  ('Filipp Munawer',),
#  ('Sugwoo Dulin',),
#  ('Yishay Decleir',),
#  ('Somnath Parascandalo',),
#  ('Pranjal Billawala',),
#  ('Chiradeep Furedi',),
#  ('Masako Schiper',),
#  ('Flemming Baezner',),
#  ('Chinya Deyuan',),
#  ('Sumali Candan',),
#  ('Shin Foote',),
#  ('Munehiro Aingworth',),
#  ('Zhensheng Juneja',),
#  ('Arve Erde',),
#  ('Divine Aingworth',),
#  ('Chenye Hertweck',),
#  ('Matk Rahimi',),
#  ('Alselm Parascandalo',),
#  ('Marlo Kandlur',),
#  ('Insup Benveniste',),
#  ('Alain Bonifati',),
#  ...]

# %% [markdown]
# ### Find all employees who are also managers

# %%
# %%sql
# SELECT e.emp_no
# FROM employees AS e
# JOIN dept_manager AS m ON e.emp_no = m.emp_no
# Out:
#  * mysql+pymysql://miguel:***@localhost:3306/employees
# 24 rows affected.
# [(110022,),
#  (110039,),
#  (110085,),
#  (110114,),
#  (110183,),
#  (110228,),
#  (110303,),
#  (110344,),
#  (110386,),
#  (110420,),
#  (110511,),
#  (110567,),
#  (110725,),
#  (110765,),
#  (110800,),
#  (110854,),
#  (111035,),
#  (111133,),
#  (111400,),
#  (111534,),
#  (111692,),
#  (111784,),
#  (111877,),
#  (111939,)]

# %% [markdown]
# ### Find the 5th highest salary

# %% [markdown]
# Let's first see the top 10 salaries.

# %%
# %%sql
# SELECT salary
# FROM salaries
# ORDER BY salary DESC
# LIMIT 10
# Out:
#  * mysql+pymysql://miguel:***@localhost:3306/employees
# 10 rows affected.
# [(158220,),
#  (157821,),
#  (156286,),
#  (155709,),
#  (155513,),
#  (155377,),
#  (155190,),
#  (154888,),
#  (154885,),
#  (154459,)]

# %%
# %%sql
# SELECT salary
# FROM salaries
# ORDER BY salary DESC
# LIMIT 1
# OFFSET 4
# Out:
#  * mysql+pymysql://miguel:***@localhost:3306/employees
# 1 rows affected.
# [(155513,)]

# %% [markdown]
# ### Find duplicate rows in the employees table
# Since this table doesn't have exact duplicates, let's find rows for the same employee and birth date.

# %%
# %%sql
# SELECT
#     first_name,
#     last_name,
#     birth_date,
#     COUNT(*)
# FROM employees
# GROUP BY
#     first_name,
#     last_name,
#     birth_date
# HAVING COUNT(*) > 1
# Out:
#  * mysql+pymysql://miguel:***@localhost:3306/employees
# 6 rows affected.
# [('Sarita', 'Ghalwash', datetime.date(1963, 12, 8), 2),
#  ('Holgard', 'Negoita', datetime.date(1963, 7, 19), 2),
#  ('Pragnesh', 'Acton', datetime.date(1958, 5, 12), 2),
#  ('Shim', 'Gide', datetime.date(1963, 7, 10), 2),
#  ('Tonny', 'Cromarty', datetime.date(1963, 5, 7), 2),
#  ('Pintsang', 'Granlund', datetime.date(1956, 11, 25), 2)]

# %% [markdown]
# ### Show unique job titles per department

# %%
# %%sql
# SELECT DISTINCT
#     dept_name,
#     title
# FROM employees AS e
# JOIN titles AS t ON e.emp_no = t.emp_no
# JOIN dept_emp AS de ON e.emp_no = de.emp_no
# JOIN departments AS d ON de.dept_no = d.dept_no
# Out:
#  * mysql+pymysql://miguel:***@localhost:3306/employees
# 45 rows affected.
# [('Customer Service', 'Staff'),
#  ('Customer Service', 'Senior Staff'),
#  ('Customer Service', 'Engineer'),
#  ('Customer Service', 'Senior Engineer'),
#  ('Customer Service', 'Assistant Engineer'),
#  ('Customer Service', 'Technique Leader'),
#  ('Customer Service', 'Manager'),
#  ('Development', 'Senior Engineer'),
#  ('Development', 'Assistant Engineer'),
#  ('Development', 'Engineer'),
#  ('Development', 'Technique Leader'),
#  ('Development', 'Senior Staff'),
#  ('Development', 'Staff'),
#  ('Development', 'Manager'),
#  ('Finance', 'Senior Staff'),
#  ('Finance', 'Staff'),
#  ('Finance', 'Manager'),
#  ('Human Resources', 'Senior Staff'),
#  ('Human Resources', 'Staff'),
#  ('Human Resources', 'Manager'),
#  ('Marketing', 'Senior Staff'),
#  ('Marketing', 'Staff'),
#  ('Marketing', 'Manager'),
#  ('Production', 'Senior Engineer'),
#  ('Production', 'Engineer'),
#  ('Production', 'Assistant Engineer'),
#  ('Production', 'Technique Leader'),
#  ('Production', 'Senior Staff'),
#  ('Production', 'Staff'),
#  ('Production', 'Manager'),
#  ('Quality Management', 'Assistant Engineer'),
#  ('Quality Management', 'Engineer'),
#  ('Quality Management', 'Senior Engineer'),
#  ('Quality Management', 'Technique Leader'),
#  ('Quality Management', 'Manager'),
#  ('Research', 'Senior Staff'),
#  ('Research', 'Staff'),
#  ('Research', 'Engineer'),
#  ('Research', 'Senior Engineer'),
#  ('Research', 'Technique Leader'),
#  ('Research', 'Assistant Engineer'),
#  ('Research', 'Manager'),
#  ('Sales', 'Staff'),
#  ('Sales', 'Senior Staff'),
#  ('Sales', 'Manager')]

# %% [markdown]
# ## Aggregating

# %% [markdown]
# ### Show the average salaries per job title
# Order by average salary (descending)

# %%
# %%sql
# SELECT
#     title,
#     ROUND(AVG(salary), 0) AS avg_salary
# FROM titles AS t
# JOIN salaries AS s ON t.emp_no = s.emp_no
# GROUP BY title
# ORDER BY avg_salary DESC
# Out:
#  * mysql+pymysql://miguel:***@localhost:3306/employees
# 7 rows affected.
# [('Senior Staff', Decimal('70471')),
#  ('Staff', Decimal('69309')),
#  ('Manager', Decimal('66924')),
#  ('Senior Engineer', Decimal('60543')),
#  ('Engineer', Decimal('59508')),
#  ('Assistant Engineer', Decimal('59305')),
#  ('Technique Leader', Decimal('59294'))]

# %% [markdown]
# ### Show the total number of employees per job title and the percentage of the total per title
# Order by employee count (descending)

# %% [markdown]
# Using a Common Table Expression:

# %%
# %%sql
# WITH salary_cte
# AS (
#     SELECT
#     title,
#     COUNT(*) AS emp_count
#     FROM titles
#     GROUP BY title
# )
# SELECT
#     title,
#     emp_count,
#     (emp_count / (SELECT COUNT(*) FROM titles) * 100) AS percent_of_total
# FROM salary_cte
# ORDER BY emp_count DESC
# Out:
#  * mysql+pymysql://miguel:***@localhost:3306/employees
# 7 rows affected.
# [('Engineer', 115003, Decimal('25.9420')),
#  ('Staff', 107391, Decimal('24.2249')),
#  ('Senior Engineer', 97750, Decimal('22.0501')),
#  ('Senior Staff', 92853, Decimal('20.9455')),
#  ('Technique Leader', 15159, Decimal('3.4195')),
#  ('Assistant Engineer', 15128, Decimal('3.4125')),
#  ('Manager', 24, Decimal('0.0054'))]

# %% [markdown]
# Using a subquery:

# %%
# %%sql
# SELECT
#     title,
#     emp_count,
#     (emp_count / (SELECT COUNT(*) FROM titles) * 100) AS percent_of_total
# FROM (
# SELECT
#     title,
#     COUNT(*) AS emp_count
# FROM titles
# GROUP BY title
# ORDER BY emp_count DESC
# ) a
# Out:
#  * mysql+pymysql://miguel:***@localhost:3306/employees
# 7 rows affected.
# [('Engineer', 115003, Decimal('25.9420')),
#  ('Staff', 107391, Decimal('24.2249')),
#  ('Senior Engineer', 97750, Decimal('22.0501')),
#  ('Senior Staff', 92853, Decimal('20.9455')),
#  ('Technique Leader', 15159, Decimal('3.4195')),
#  ('Assistant Engineer', 15128, Decimal('3.4125')),
#  ('Manager', 24, Decimal('0.0054'))]

# %% [markdown]
# ### Group employees into 3 salary groups
# 0-50k, 50-100k, >100k

# %% [markdown]
# First, let's see the max, min, and average salaries. This will give us an idea of how to group the salaries.

# %%
# %%sql
# SELECT
#     MAX(salary),
#     MIN(salary),
#     AVG(salary)
# FROM salaries
# Out:
#  * mysql+pymysql://miguel:***@localhost:3306/employees
# 1 rows affected.
# [(158220, 38623, Decimal('63810.7448'))]

# %%
# %%sql
# SELECT
#     CASE
#         WHEN salary < 50000 THEN '0-50k'
#         WHEN salary > 100000 THEN '> 100k'
#         ELSE '50k-100k'
#     END AS salary_group,
#     COUNT(*) AS emp_count
# FROM salaries
# GROUP BY salary_group
# ORDER BY emp_count DESC
# Out:
#  * mysql+pymysql://miguel:***@localhost:3306/employees
# 3 rows affected.
# [('50k-100k', 2071823), ('0-50k', 677528), ('> 100k', 94696)]

# %% [markdown]
# ## Joining

# %% [markdown]
# ### Show all employees and include their employee id, full names, job titles, and the department name
# It might be good to also include the from_date and to_date from the salaries table.

# %%
# %%sql
# SELECT
#     e.emp_no,
#     CONCAT(first_name, ' ', last_name) AS emp_name,
#     t.title,
#     d.dept_name,
#     s.from_date,
#     s.to_date,
#     s.salary
# FROM employees AS e
# JOIN dept_emp AS de ON e.emp_no = de.emp_no
# JOIN departments AS d ON de.dept_no = d.dept_no
# JOIN titles AS t ON e.emp_no = t.emp_no
# JOIN salaries AS s ON e.emp_no = s.emp_no
# LIMIT 10
# Out:
#  * mysql+pymysql://miguel:***@localhost:3306/employees
# 10 rows affected.
# [(10011, 'Mary Sluis', 'Staff', 'Customer Service', datetime.date(1990, 1, 22), datetime.date(1991, 1, 22), 42365),
#  (10011, 'Mary Sluis', 'Staff', 'Customer Service', datetime.date(1991, 1, 22), datetime.date(1992, 1, 22), 44200),
#  (10011, 'Mary Sluis', 'Staff', 'Customer Service', datetime.date(1992, 1, 22), datetime.date(1993, 1, 21), 48214),
#  (10011, 'Mary Sluis', 'Staff', 'Customer Service', datetime.date(1993, 1, 21), datetime.date(1994, 1, 21), 50927),
#  (10011, 'Mary Sluis', 'Staff', 'Customer Service', datetime.date(1994, 1, 21), datetime.date(1995, 1, 21), 51470),
#  (10011, 'Mary Sluis', 'Staff', 'Customer Service', datetime.date(1995, 1, 21), datetime.date(1996, 1, 21), 54545),
#  (10011, 'Mary Sluis', 'Staff', 'Customer Service', datetime.date(1996, 1, 21), datetime.date(1996, 11, 9), 56753),
#  (10038, 'Huan Lortz', 'Senior Staff', 'Customer Service', datetime.date(1989, 9, 20), datetime.date(1990, 9, 20), 40000),
#  (10038, 'Huan Lortz', 'Senior Staff', 'Customer Service', datetime.date(1990, 9, 20), datetime.date(1991, 9, 20), 43527),
#  (10038, 'Huan Lortz', 'Senior Staff', 'Customer Service', datetime.date(1991, 9, 20), datetime.date(1992, 9, 19), 46509)]
